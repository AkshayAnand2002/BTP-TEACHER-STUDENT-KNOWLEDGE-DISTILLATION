# %%
# Install required libraries
# !pip install opendatasets --upgrade --quiet
# !pip install kaggle --quiet

# Import libraries for downloading the dataset
import opendatasets as od
import os
import random
import cv2
import numpy as np
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from keras.callbacks import LearningRateScheduler
from keras.optimizers import SGD
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input
from keras.models import Model
import tensorflow as tf
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score, classification_report
import time

# Download dataset from Kaggle
dataset_url = 'https://www.kaggle.com/datasets/jiayuanchengala/aid-scene-classification-datasets'
od.download(dataset_url)

# Set the path to the image folder
data_path = 'aid-scene-classification-datasets/AID'

# Initialize image data and labels
image_data = []
labels = []

# Load the image dataset
for root, dirs, files in os.walk(data_path):
    for file in files:
        if file.endswith(".jpg"):
            # Read the image
            image = cv2.imread(os.path.join(root, file))
            image = cv2.resize(image, (32, 32))  # Resize
            image = img_to_array(image)
            image_data.append(image)

            # Use the folder name as the label
            label = root.split(os.path.sep)[-1]
            labels.append(label)

# Convert to numpy arrays and normalize the images
image_data = np.array(image_data, dtype="float") / 255.0
labels = np.array(labels)

# Binarize the labels
lb = LabelBinarizer()
labels = lb.fit_transform(labels)

# Split the dataset into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(image_data, labels, test_size=0.2, random_state=42)

print(f'Training samples: {len(x_train)}, Testing samples: {len(x_test)}')

# Define the teacher model (more layers)
def teacher_model(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(512, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)

    x = Flatten()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

# Define the student model (fewer layers)
def student_model(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)

    x = Flatten()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

input_shape = (32, 32, 3)  # Updated input shape
num_classes = len(lb.classes_)

# Build teacher and student models
teacher = teacher_model(input_shape, num_classes)
student = student_model(input_shape, num_classes)

# Define a learning rate scheduler function
def lr_scheduler(epoch, lr):
    return float(lr * tf.math.exp(-0.1)) if epoch >= 10 else float(lr)

# Compile and train the teacher model
teacher.compile(optimizer=SGD(learning_rate=1e-2, momentum=0.9), loss='categorical_crossentropy', metrics=['accuracy'])
teacher.fit(x_train, y_train, batch_size=32, epochs=15, validation_data=(x_test, y_test), callbacks=[LearningRateScheduler(lr_scheduler)])

# Precompute teacher's predictions for distillation
teacher_preds = teacher.predict(x_train)

# Define distillation loss function
def distillation_loss(y_true, y_pred, teacher_preds, temperature=3.0, alpha=0.1):
    teacher_batch_preds = tf.gather(teacher_preds, tf.range(tf.shape(y_pred)[0]))
    y_true = tf.keras.activations.softmax(y_true / temperature)
    y_pred = tf.keras.activations.softmax(y_pred / temperature)
    teacher_batch_preds = tf.keras.activations.softmax(teacher_batch_preds / temperature)
    soft_loss = tf.keras.losses.categorical_crossentropy(teacher_batch_preds, y_pred)
    hard_loss = tf.keras.losses.categorical_crossentropy(y_true, y_pred)
    return alpha * soft_loss + (1. - alpha) * hard_loss

# Compile and train the student model using distillation loss with Adam optimizer
teacher_score = teacher.evaluate(x_test, y_test, verbose=0)

print(f'Teacher test accuracy: {teacher_score[1] * 100:.2f}%')
student.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3), loss=lambda y_true, y_pred: distillation_loss(y_true, y_pred, teacher_preds), metrics=['accuracy'])
student.fit(x_train, y_train, batch_size=32, epochs=30, validation_data=(x_test, y_test), callbacks=[LearningRateScheduler(lr_scheduler)])

# Evaluate models
student_score = student.evaluate(x_test, y_test, verbose=0)
print(f'Student test accuracy: {student_score[1] * 100:.2f}%')
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: akshayanand2002
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/jiayuanchengala/aid-scene-classification-datasets
# Downloading aid-scene-classification-datasets.zip to ./aid-scene-classification-datasets
# 100%|██████████| 2.45G/2.45G [01:57<00:00, 22.5MB/s]
# Training samples: 8000, Testing samples: 2000
# Epoch 1/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 95s 372ms/step - accuracy: 0.0487 - loss: 3.3497 - val_accuracy: 0.1300 - val_loss: 2.9169 - learning_rate: 0.0100
# Epoch 2/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 143s 379ms/step - accuracy: 0.1663 - loss: 2.8234 - val_accuracy: 0.2460 - val_loss: 2.5074 - learning_rate: 0.0100
# Epoch 3/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 141s 374ms/step - accuracy: 0.2853 - loss: 2.3872 - val_accuracy: 0.3770 - val_loss: 2.0661 - learning_rate: 0.0100
# Epoch 4/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 145s 385ms/step - accuracy: 0.3697 - loss: 2.0532 - val_accuracy: 0.3845 - val_loss: 1.9838 - learning_rate: 0.0100
# Epoch 5/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 139s 375ms/step - accuracy: 0.4209 - loss: 1.8722 - val_accuracy: 0.4995 - val_loss: 1.6699 - learning_rate: 0.0100
# Epoch 6/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 144s 382ms/step - accuracy: 0.4829 - loss: 1.6528 - val_accuracy: 0.4765 - val_loss: 1.6978 - learning_rate: 0.0100
# Epoch 7/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 142s 383ms/step - accuracy: 0.5434 - loss: 1.4864 - val_accuracy: 0.5250 - val_loss: 1.5411 - learning_rate: 0.0100
# Epoch 8/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 141s 379ms/step - accuracy: 0.5529 - loss: 1.4249 - val_accuracy: 0.5455 - val_loss: 1.4595 - learning_rate: 0.0100
# Epoch 9/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 140s 372ms/step - accuracy: 0.5911 - loss: 1.2997 - val_accuracy: 0.5435 - val_loss: 1.4590 - learning_rate: 0.0100
# Epoch 10/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 143s 377ms/step - accuracy: 0.6237 - loss: 1.1803 - val_accuracy: 0.5760 - val_loss: 1.3521 - learning_rate: 0.0100
# Epoch 11/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 143s 382ms/step - accuracy: 0.6679 - loss: 1.0538 - val_accuracy: 0.6055 - val_loss: 1.3058 - learning_rate: 0.0090
# Epoch 12/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 95s 380ms/step - accuracy: 0.7290 - loss: 0.8528 - val_accuracy: 0.5995 - val_loss: 1.2651 - learning_rate: 0.0082
# Epoch 13/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 140s 371ms/step - accuracy: 0.7500 - loss: 0.7615 - val_accuracy: 0.6310 - val_loss: 1.2801 - learning_rate: 0.0074
# Epoch 14/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 144s 381ms/step - accuracy: 0.7929 - loss: 0.6173 - val_accuracy: 0.6210 - val_loss: 1.3200 - learning_rate: 0.0067
# Epoch 15/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 140s 374ms/step - accuracy: 0.8510 - loss: 0.4698 - val_accuracy: 0.6290 - val_loss: 1.3437 - learning_rate: 0.0061
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 97ms/step
# Teacher test accuracy: 62.90%
# Epoch 1/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 23s 86ms/step - accuracy: 0.0513 - loss: 3.4012 - val_accuracy: 0.1315 - val_loss: 3.4011 - learning_rate: 0.0010
# Epoch 2/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 23s 92ms/step - accuracy: 0.1904 - loss: 3.4011 - val_accuracy: 0.3100 - val_loss: 3.4009 - learning_rate: 0.0010
# Epoch 3/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 22s 89ms/step - accuracy: 0.3387 - loss: 3.4008 - val_accuracy: 0.3885 - val_loss: 3.4008 - learning_rate: 0.0010
# Epoch 4/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 22s 87ms/step - accuracy: 0.3904 - loss: 3.4007 - val_accuracy: 0.4460 - val_loss: 3.4006 - learning_rate: 0.0010
# Epoch 5/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 40s 85ms/step - accuracy: 0.4532 - loss: 3.4006 - val_accuracy: 0.4890 - val_loss: 3.4006 - learning_rate: 0.0010
# Epoch 6/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 90ms/step - accuracy: 0.4849 - loss: 3.4006 - val_accuracy: 0.4890 - val_loss: 3.4006 - learning_rate: 0.0010
# Epoch 7/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 93ms/step - accuracy: 0.5178 - loss: 3.4005 - val_accuracy: 0.5030 - val_loss: 3.4006 - learning_rate: 0.0010
# Epoch 8/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 84ms/step - accuracy: 0.5252 - loss: 3.4005 - val_accuracy: 0.5425 - val_loss: 3.4005 - learning_rate: 0.0010
# Epoch 9/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 90ms/step - accuracy: 0.5731 - loss: 3.4004 - val_accuracy: 0.5685 - val_loss: 3.4004 - learning_rate: 0.0010
# Epoch 10/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 92ms/step - accuracy: 0.5939 - loss: 3.4004 - val_accuracy: 0.5675 - val_loss: 3.4004 - learning_rate: 0.0010
# Epoch 11/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 92ms/step - accuracy: 0.6280 - loss: 3.4003 - val_accuracy: 0.5820 - val_loss: 3.4004 - learning_rate: 9.0484e-04
# Epoch 12/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 40s 90ms/step - accuracy: 0.6397 - loss: 3.4003 - val_accuracy: 0.6045 - val_loss: 3.4003 - learning_rate: 8.1873e-04
# Epoch 13/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 92ms/step - accuracy: 0.6563 - loss: 3.4002 - val_accuracy: 0.6095 - val_loss: 3.4003 - learning_rate: 7.4082e-04
# Epoch 14/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.6813 - loss: 3.4002 - val_accuracy: 0.6045 - val_loss: 3.4003 - learning_rate: 6.7032e-04
# Epoch 15/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 93ms/step - accuracy: 0.7154 - loss: 3.4001 - val_accuracy: 0.6040 - val_loss: 3.4004 - learning_rate: 6.0653e-04
# Epoch 16/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 40s 91ms/step - accuracy: 0.7182 - loss: 3.4001 - val_accuracy: 0.6060 - val_loss: 3.4003 - learning_rate: 5.4881e-04
# Epoch 17/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 91ms/step - accuracy: 0.7384 - loss: 3.4001 - val_accuracy: 0.6175 - val_loss: 3.4003 - learning_rate: 4.9659e-04
# Epoch 18/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 91ms/step - accuracy: 0.7515 - loss: 3.4000 - val_accuracy: 0.6210 - val_loss: 3.4003 - learning_rate: 4.4933e-04
# Epoch 19/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 23s 90ms/step - accuracy: 0.7589 - loss: 3.4000 - val_accuracy: 0.6230 - val_loss: 3.4003 - learning_rate: 4.0657e-04
# Epoch 20/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 93ms/step - accuracy: 0.7777 - loss: 3.4000 - val_accuracy: 0.6370 - val_loss: 3.4003 - learning_rate: 3.6788e-04
# Epoch 21/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 85ms/step - accuracy: 0.7778 - loss: 3.4000 - val_accuracy: 0.6315 - val_loss: 3.4003 - learning_rate: 3.3287e-04
# Epoch 22/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 90ms/step - accuracy: 0.7931 - loss: 3.3999 - val_accuracy: 0.6365 - val_loss: 3.4003 - learning_rate: 3.0119e-04
# Epoch 23/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 92ms/step - accuracy: 0.8070 - loss: 3.3999 - val_accuracy: 0.6355 - val_loss: 3.4003 - learning_rate: 2.7253e-04
# Epoch 24/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 91ms/step - accuracy: 0.8090 - loss: 3.3999 - val_accuracy: 0.6400 - val_loss: 3.4003 - learning_rate: 2.4660e-04
# Epoch 25/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 22s 87ms/step - accuracy: 0.8273 - loss: 3.3999 - val_accuracy: 0.6390 - val_loss: 3.4003 - learning_rate: 2.2313e-04
# Epoch 26/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 43s 95ms/step - accuracy: 0.8284 - loss: 3.3998 - val_accuracy: 0.6375 - val_loss: 3.4003 - learning_rate: 2.0190e-04
# Epoch 27/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 94ms/step - accuracy: 0.8363 - loss: 3.3998 - val_accuracy: 0.6415 - val_loss: 3.4003 - learning_rate: 1.8268e-04
# Epoch 28/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 96ms/step - accuracy: 0.8368 - loss: 3.3998 - val_accuracy: 0.6425 - val_loss: 3.4003 - learning_rate: 1.6530e-04
# Epoch 29/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 22s 86ms/step - accuracy: 0.8383 - loss: 3.3998 - val_accuracy: 0.6430 - val_loss: 3.4003 - learning_rate: 1.4957e-04
# Epoch 30/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 43s 93ms/step - accuracy: 0.8466 - loss: 3.3998 - val_accuracy: 0.6395 - val_loss: 3.4003 - learning_rate: 1.3534e-04
# Student test accuracy: 63.95%

# %%
# Evaluate the teacher model
teacher_score = teacher.evaluate(x_test, y_test, verbose=0)

print(f'Teacher test accuracy: {teacher_score[1] * 100:.2f}%')

# Generate predictions from the teacher model
teacher_preds_probs = teacher.predict(x_test)
teacher_preds = np.argmax(teacher_preds_probs, axis=1)
y_true = np.argmax(y_test, axis=1)

# Print the classification report for the teacher model
print("=== Teacher Model Classification Report ===")
print(classification_report(y_true, teacher_preds, target_names=lb.classes_))
# Out:
# Teacher test accuracy: 62.90%
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 163ms/step
# === Teacher Model Classification Report ===
#                    precision    recall  f1-score   support
#
#           Airport       0.54      0.58      0.56        74
#          BareLand       0.82      0.58      0.68        62
#     BaseballField       0.97      0.80      0.88        46
#             Beach       0.83      0.85      0.84        61
#            Bridge       0.81      0.76      0.79        75
#            Center       0.78      0.64      0.71        45
#            Church       0.49      0.44      0.46        52
#        Commercial       0.53      0.53      0.53        79
#  DenseResidential       0.53      0.76      0.62        80
#            Desert       0.67      0.90      0.77        48
#          Farmland       0.57      0.57      0.57        70
#            Forest       0.77      0.92      0.84        52
#        Industrial       0.48      0.58      0.53        72
#            Meadow       0.83      0.89      0.86        64
# MediumResidential       0.53      0.64      0.58        59
#          Mountain       0.65      0.42      0.51        73
#              Park       0.52      0.61      0.56        84
#           Parking       0.84      0.69      0.76        61
#        Playground       0.88      0.67      0.76        66
#              Pond       0.73      0.82      0.77        89
#              Port       0.81      0.74      0.77        80
#    RailwayStation       0.58      0.29      0.38        52
#            Resort       0.41      0.30      0.34        54
#             River       0.45      0.56      0.50        71
#            School       0.33      0.22      0.26        64
# SparseResidential       0.90      0.75      0.82        57
#            Square       0.31      0.41      0.35        66
#           Stadium       0.92      0.92      0.92        66
#      StorageTanks       0.54      0.72      0.62        75
#           Viaduct       0.47      0.39      0.43       103
#
#          accuracy                           0.63      2000
#         macro avg       0.65      0.63      0.63      2000
#      weighted avg       0.64      0.63      0.63      2000

# %%
student_score = student.evaluate(x_test, y_test, verbose=0)
print(f'Student test accuracy: {student_score[1] * 100:.2f}%')
# Out:
# Student test accuracy: 63.95%

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.callbacks import LearningRateScheduler
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score, classification_report
import matplotlib.pyplot as plt
import time

# Assuming x_train, y_train, x_test, y_test, and teacher_preds are already defined

# Initialize lists to store metrics
alpha_values = [0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
f1_scores = []
accuracies = []
precisions = []
recalls = []
inference_times = []

# Precompute teacher's predictions for distillation
teacher_preds = teacher.predict(x_train)

# Function to evaluate F1-score, accuracy, precision, recall, and inference time for a given model and alpha
def evaluate_student_with_alpha(alpha):
    # Define distillation loss function with current alpha
    def distillation_loss(y_true, y_pred, teacher_preds, temperature=3.0, alpha=0.1):
      teacher_batch_preds = tf.gather(teacher_preds, tf.range(tf.shape(y_pred)[0]))
      y_true = tf.keras.activations.softmax(y_true / temperature)
      y_pred = tf.keras.activations.softmax(y_pred / temperature)
      teacher_batch_preds = tf.keras.activations.softmax(teacher_batch_preds / temperature)
      soft_loss = tf.keras.losses.categorical_crossentropy(teacher_batch_preds, y_pred)
      hard_loss = tf.keras.losses.categorical_crossentropy(y_true, y_pred)
      return alpha * soft_loss + (1. - alpha) * hard_loss

    # Compile the student model with the new distillation loss
    student.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
                    loss=lambda y_true, y_pred: distillation_loss(y_true, y_pred, teacher_preds),
                    metrics=['accuracy'])

    # Train the student model
    student.fit(x_train, y_train, batch_size=32, epochs=30, validation_data=(x_test, y_test),
                callbacks=[LearningRateScheduler(lambda epoch: 1e-3 * (0.1 ** (epoch // 10)))], verbose=0)

    # Predict and evaluate
    start_time = time.time()
    y_pred_probs = student.predict(x_test)
    inference_time = time.time() - start_time
    y_pred = np.argmax(y_pred_probs, axis=1)
    y_true = np.argmax(y_test, axis=1)

    # Calculate and store metrics
    f1 = f1_score(y_true, y_pred, average='weighted')
    acc = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted')
    recall = recall_score(y_true, y_pred, average='weighted')

    # Append the results
    f1_scores.append(f1)
    accuracies.append(acc)
    precisions.append(precision)
    recalls.append(recall)
    inference_times.append(inference_time)

    # Print classification report
    print(f"=== Classification Report for Alpha: {alpha} ===")
    print(classification_report(y_true, y_pred, target_names=lb.classes_))
    print(f"Inference Time: {inference_time:.4f} seconds\n")
    print(f"Alpha: {alpha} - F1 Score: {f1:.4f}, Accuracy: {acc:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}")

# Run evaluation for each alpha
for alpha in alpha_values:
    evaluate_student_with_alpha(alpha)

# Plot F1-Score vs. Alpha
plt.figure(figsize=(7, 5))
plt.plot(alpha_values, f1_scores, marker='o', color='b')
plt.xlabel("Alpha Values")
plt.ylabel("F1-Score Of Student Model")
plt.grid(True)
plt.savefig("f1_score_vs_alpha.pdf")
plt.show()

# Plot Accuracy vs. Alpha
plt.figure(figsize=(7, 5))
plt.plot(alpha_values, accuracies, marker='o', color='g')
plt.xlabel("Alpha Values")
plt.ylabel("Accuracy Of Student Model")
plt.grid(True)
plt.savefig("accuracy_vs_alpha.pdf")
plt.show()

# Plot Precision vs. Alpha
plt.figure(figsize=(7, 5))
plt.plot(alpha_values, precisions, marker='o', color='orange')
plt.xlabel("Alpha Values")
plt.ylabel("Precision Of Student Model")
plt.grid(True)
plt.savefig("precision_vs_alpha.pdf")
plt.show()

# Plot Recall vs. Alpha
plt.figure(figsize=(7, 5))
plt.plot(alpha_values, recalls, marker='o', color='red')
plt.xlabel("Alpha Values")
plt.ylabel("Recall Of Student Model")
plt.grid(True)
plt.savefig("recall_vs_alpha.pdf")
plt.show()

# Plot Inference Time vs. Alpha
plt.figure(figsize=(7, 5))
plt.plot(alpha_values, inference_times, marker='o', color='purple')
plt.xlabel("Alpha Values")
plt.ylabel("Inference Time Of Student Model (in seconds)")
plt.grid(True)
plt.savefig("inference_time_vs_alpha.pdf")
plt.show()
# Out:
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 43s 173ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# === Classification Report for Alpha: 0.0 ===
#                    precision    recall  f1-score   support
#
#           Airport       0.53      0.65      0.59        74
#          BareLand       0.77      0.74      0.75        62
#     BaseballField       0.93      0.85      0.89        46
#             Beach       0.78      0.85      0.81        61
#            Bridge       0.86      0.80      0.83        75
#            Center       0.67      0.64      0.66        45
#            Church       0.49      0.35      0.40        52
#        Commercial       0.57      0.54      0.56        79
#  DenseResidential       0.54      0.69      0.61        80
#            Desert       0.78      0.88      0.82        48
#          Farmland       0.55      0.56      0.55        70
#            Forest       0.94      0.92      0.93        52
#        Industrial       0.43      0.40      0.41        72
#            Meadow       0.82      0.88      0.85        64
# MediumResidential       0.59      0.56      0.57        59
#          Mountain       0.64      0.58      0.60        73
#              Park       0.65      0.57      0.61        84
#           Parking       0.66      0.74      0.70        61
#        Playground       0.71      0.79      0.75        66
#              Pond       0.85      0.81      0.83        89
#              Port       0.80      0.82      0.81        80
#    RailwayStation       0.41      0.38      0.40        52
#            Resort       0.49      0.44      0.47        54
#             River       0.49      0.59      0.54        71
#            School       0.26      0.20      0.23        64
# SparseResidential       0.86      0.75      0.80        57
#            Square       0.41      0.36      0.39        66
#           Stadium       0.82      0.89      0.86        66
#      StorageTanks       0.59      0.59      0.59        75
#           Viaduct       0.46      0.50      0.48       103
#
#          accuracy                           0.64      2000
#         macro avg       0.64      0.64      0.64      2000
#      weighted avg       0.64      0.64      0.64      2000
#
# Inference Time: 1.5955 seconds
#
# Alpha: 0.0 - F1 Score: 0.6380, Accuracy: 0.6410, Precision: 0.6390, Recall: 0.6410
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# === Classification Report for Alpha: 0.05 ===
#                    precision    recall  f1-score   support
#
#           Airport       0.50      0.61      0.55        74
#          BareLand       0.71      0.71      0.71        62
#     BaseballField       0.95      0.89      0.92        46
#             Beach       0.79      0.90      0.84        61
#            Bridge       0.82      0.77      0.79        75
#            Center       0.63      0.64      0.64        45
#            Church       0.42      0.27      0.33        52
#        Commercial       0.49      0.51      0.50        79
#  DenseResidential       0.50      0.66      0.57        80
#            Desert       0.76      0.85      0.80        48
#          Farmland       0.60      0.57      0.58        70
#            Forest       0.92      0.90      0.91        52
#        Industrial       0.43      0.40      0.41        72
#            Meadow       0.85      0.89      0.87        64
# MediumResidential       0.64      0.59      0.61        59
#          Mountain       0.61      0.53      0.57        73
#              Park       0.62      0.52      0.57        84
#           Parking       0.68      0.77      0.72        61
#        Playground       0.75      0.85      0.79        66
#              Pond       0.87      0.80      0.83        89
#              Port       0.81      0.81      0.81        80
#    RailwayStation       0.37      0.40      0.39        52
#            Resort       0.46      0.43      0.44        54
#             River       0.52      0.61      0.56        71
#            School       0.23      0.19      0.21        64
# SparseResidential       0.86      0.74      0.79        57
#            Square       0.32      0.32      0.32        66
#           Stadium       0.86      0.89      0.87        66
#      StorageTanks       0.58      0.60      0.59        75
#           Viaduct       0.48      0.43      0.45       103
#
#          accuracy                           0.63      2000
#         macro avg       0.63      0.64      0.63      2000
#      weighted avg       0.63      0.63      0.63      2000
#
# Inference Time: 2.6332 seconds
#
# Alpha: 0.05 - F1 Score: 0.6268, Accuracy: 0.6300, Precision: 0.6284, Recall: 0.6300
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# === Classification Report for Alpha: 0.1 ===
#                    precision    recall  f1-score   support
#
#           Airport       0.56      0.58      0.57        74
#          BareLand       0.71      0.76      0.73        62
#     BaseballField       0.93      0.91      0.92        46
#             Beach       0.83      0.87      0.85        61
#            Bridge       0.79      0.77      0.78        75
#            Center       0.64      0.71      0.67        45
#            Church       0.47      0.38      0.42        52
#        Commercial       0.59      0.54      0.57        79
#  DenseResidential       0.52      0.70      0.60        80
#            Desert       0.78      0.83      0.81        48
#          Farmland       0.58      0.51      0.55        70
#            Forest       0.94      0.92      0.93        52
#        Industrial       0.40      0.42      0.41        72
#            Meadow       0.77      0.86      0.81        64
# MediumResidential       0.64      0.61      0.63        59
#          Mountain       0.57      0.53      0.55        73
#              Park       0.67      0.57      0.62        84
#           Parking       0.68      0.77      0.72        61
#        Playground       0.75      0.82      0.78        66
#              Pond       0.85      0.80      0.82        89
#              Port       0.82      0.84      0.83        80
#    RailwayStation       0.41      0.46      0.43        52
#            Resort       0.45      0.46      0.46        54
#             River       0.50      0.62      0.55        71
#            School       0.32      0.25      0.28        64
# SparseResidential       0.90      0.77      0.83        57
#            Square       0.44      0.33      0.38        66
#           Stadium       0.85      0.88      0.87        66
#      StorageTanks       0.52      0.59      0.55        75
#           Viaduct       0.52      0.42      0.46       103
#
#          accuracy                           0.64      2000
#         macro avg       0.65      0.65      0.65      2000
#      weighted avg       0.64      0.64      0.64      2000
#
# Inference Time: 2.6339 seconds
#
# Alpha: 0.1 - F1 Score: 0.6394, Accuracy: 0.6425, Precision: 0.6412, Recall: 0.6425
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# === Classification Report for Alpha: 0.15 ===
#                    precision    recall  f1-score   support
#
#           Airport       0.49      0.53      0.51        74
#          BareLand       0.71      0.73      0.72        62
#     BaseballField       0.83      0.93      0.88        46
#             Beach       0.85      0.87      0.86        61
#            Bridge       0.80      0.75      0.77        75
#            Center       0.63      0.64      0.64        45
#            Church       0.49      0.33      0.39        52
#        Commercial       0.51      0.47      0.49        79
#  DenseResidential       0.50      0.68      0.58        80
#            Desert       0.76      0.81      0.79        48
#          Farmland       0.56      0.53      0.54        70
#            Forest       0.94      0.94      0.94        52
#        Industrial       0.41      0.46      0.43        72
#            Meadow       0.86      0.88      0.87        64
# MediumResidential       0.59      0.61      0.60        59
#          Mountain       0.59      0.64      0.61        73
#              Park       0.63      0.55      0.59        84
#           Parking       0.69      0.79      0.73        61
#        Playground       0.75      0.80      0.77        66
#              Pond       0.86      0.80      0.83        89
#              Port       0.76      0.82      0.79        80
#    RailwayStation       0.42      0.40      0.41        52
#            Resort       0.45      0.46      0.45        54
#             River       0.54      0.62      0.58        71
#            School       0.27      0.20      0.23        64
# SparseResidential       0.83      0.75      0.79        57
#            Square       0.39      0.30      0.34        66
#           Stadium       0.87      0.89      0.88        66
#      StorageTanks       0.57      0.63      0.59        75
#           Viaduct       0.55      0.45      0.49       103
#
#          accuracy                           0.64      2000
#         macro avg       0.64      0.64      0.64      2000
#      weighted avg       0.63      0.64      0.63      2000
#
# Inference Time: 1.6023 seconds
#
# Alpha: 0.15 - F1 Score: 0.6316, Accuracy: 0.6360, Precision: 0.6320, Recall: 0.6360
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step
# === Classification Report for Alpha: 0.2 ===
#                    precision    recall  f1-score   support
#
#           Airport       0.48      0.57      0.52        74
#          BareLand       0.72      0.74      0.73        62
#     BaseballField       0.89      0.87      0.88        46
#             Beach       0.86      0.89      0.87        61
#            Bridge       0.82      0.75      0.78        75
#            Center       0.65      0.67      0.66        45
#            Church       0.37      0.29      0.32        52
#        Commercial       0.50      0.48      0.49        79
#  DenseResidential       0.49      0.66      0.56        80
#            Desert       0.76      0.79      0.78        48
#          Farmland       0.52      0.51      0.52        70
#            Forest       0.91      0.94      0.92        52
#        Industrial       0.45      0.43      0.44        72
#            Meadow       0.86      0.84      0.85        64
# MediumResidential       0.54      0.56      0.55        59
#          Mountain       0.58      0.59      0.59        73
#              Park       0.62      0.57      0.59        84
#           Parking       0.68      0.82      0.74        61
#        Playground       0.76      0.79      0.78        66
#              Pond       0.88      0.82      0.85        89
#              Port       0.83      0.81      0.82        80
#    RailwayStation       0.43      0.46      0.44        52
#            Resort       0.41      0.39      0.40        54
#             River       0.54      0.63      0.58        71
#            School       0.24      0.14      0.18        64
# SparseResidential       0.87      0.79      0.83        57
#            Square       0.28      0.27      0.28        66
#           Stadium       0.86      0.89      0.87        66
#      StorageTanks       0.61      0.65      0.63        75
#           Viaduct       0.52      0.44      0.48       103
#
#          accuracy                           0.63      2000
#         macro avg       0.63      0.64      0.63      2000
#      weighted avg       0.63      0.63      0.63      2000
#
# Inference Time: 2.6602 seconds
#
# Alpha: 0.2 - F1 Score: 0.6267, Accuracy: 0.6305, Precision: 0.6269, Recall: 0.6305
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step
# === Classification Report for Alpha: 0.25 ===
#                    precision    recall  f1-score   support
#
#           Airport       0.52      0.57      0.54        74
#          BareLand       0.72      0.76      0.74        62
#     BaseballField       0.91      0.89      0.90        46
#             Beach       0.75      0.87      0.80        61
#            Bridge       0.80      0.73      0.76        75
#            Center       0.67      0.64      0.66        45
#            Church       0.45      0.40      0.42        52
#        Commercial       0.53      0.51      0.52        79
#  DenseResidential       0.49      0.65      0.56        80
#            Desert       0.78      0.79      0.78        48
#          Farmland       0.56      0.50      0.53        70
#            Forest       0.89      0.94      0.92        52
#        Industrial       0.45      0.42      0.43        72
#            Meadow       0.83      0.84      0.84        64
# MediumResidential       0.57      0.58      0.57        59
#          Mountain       0.56      0.60      0.58        73
#              Park       0.63      0.58      0.60        84
#           Parking       0.64      0.80      0.72        61
#        Playground       0.73      0.83      0.78        66
#              Pond       0.85      0.81      0.83        89
#              Port       0.81      0.81      0.81        80
#    RailwayStation       0.39      0.37      0.38        52
#            Resort       0.48      0.41      0.44        54
#             River       0.52      0.62      0.56        71
#            School       0.24      0.16      0.19        64
# SparseResidential       0.90      0.79      0.84        57
#            Square       0.35      0.33      0.34        66
#           Stadium       0.88      0.89      0.89        66
#      StorageTanks       0.57      0.55      0.56        75
#           Viaduct       0.53      0.47      0.49       103
#
#          accuracy                           0.63      2000
#         macro avg       0.63      0.64      0.63      2000
#      weighted avg       0.63      0.63      0.63      2000
#
# Inference Time: 2.6498 seconds
#
# Alpha: 0.25 - F1 Score: 0.6277, Accuracy: 0.6320, Precision: 0.6276, Recall: 0.6320
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step
# === Classification Report for Alpha: 0.3 ===
#                    precision    recall  f1-score   support
#
#           Airport       0.51      0.57      0.54        74
#          BareLand       0.73      0.77      0.75        62
#     BaseballField       0.89      0.89      0.89        46
#             Beach       0.79      0.82      0.81        61
#            Bridge       0.80      0.79      0.79        75
#            Center       0.63      0.64      0.64        45
#            Church       0.49      0.37      0.42        52
#        Commercial       0.52      0.56      0.54        79
#  DenseResidential       0.52      0.66      0.59        80
#            Desert       0.80      0.81      0.80        48
#          Farmland       0.49      0.49      0.49        70
#            Forest       0.92      0.94      0.93        52
#        Industrial       0.42      0.44      0.43        72
#            Meadow       0.86      0.86      0.86        64
# MediumResidential       0.60      0.51      0.55        59
#          Mountain       0.53      0.58      0.55        73
#              Park       0.63      0.55      0.59        84
#           Parking       0.63      0.80      0.71        61
#        Playground       0.73      0.80      0.76        66
#              Pond       0.84      0.80      0.82        89
#              Port       0.80      0.81      0.81        80
#    RailwayStation       0.47      0.40      0.43        52
#            Resort       0.44      0.37      0.40        54
#             River       0.51      0.58      0.54        71
#            School       0.31      0.22      0.26        64
# SparseResidential       0.86      0.75      0.80        57
#            Square       0.36      0.30      0.33        66
#           Stadium       0.87      0.89      0.88        66
#      StorageTanks       0.58      0.59      0.58        75
#           Viaduct       0.44      0.44      0.44       103
#
#          accuracy                           0.63      2000
#         macro avg       0.63      0.63      0.63      2000
#      weighted avg       0.62      0.63      0.62      2000
#
# Inference Time: 2.6484 seconds
#
# Alpha: 0.3 - F1 Score: 0.6246, Accuracy: 0.6285, Precision: 0.6248, Recall: 0.6285
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step
# === Classification Report for Alpha: 0.35 ===
#                    precision    recall  f1-score   support
#
#           Airport       0.56      0.57      0.56        74
#          BareLand       0.69      0.77      0.73        62
#     BaseballField       0.89      0.91      0.90        46
#             Beach       0.78      0.82      0.80        61
#            Bridge       0.81      0.76      0.79        75
#            Center       0.73      0.71      0.72        45
#            Church       0.39      0.37      0.38        52
#        Commercial       0.54      0.52      0.53        79
#  DenseResidential       0.50      0.69      0.58        80
#            Desert       0.79      0.79      0.79        48
#          Farmland       0.55      0.51      0.53        70
#            Forest       0.89      0.94      0.92        52
#        Industrial       0.37      0.43      0.40        72
#            Meadow       0.87      0.86      0.87        64
# MediumResidential       0.58      0.53      0.55        59
#          Mountain       0.55      0.49      0.52        73
#              Park       0.60      0.58      0.59        84
#           Parking       0.71      0.80      0.75        61
#        Playground       0.70      0.80      0.75        66
#              Pond       0.82      0.82      0.82        89
#              Port       0.82      0.84      0.83        80
#    RailwayStation       0.49      0.42      0.45        52
#            Resort       0.46      0.43      0.44        54
#             River       0.51      0.61      0.55        71
#            School       0.23      0.16      0.19        64
# SparseResidential       0.88      0.74      0.80        57
#            Square       0.36      0.33      0.35        66
#           Stadium       0.86      0.85      0.85        66
#      StorageTanks       0.56      0.59      0.58        75
#           Viaduct       0.44      0.38      0.41       103
#
#          accuracy                           0.63      2000
#         macro avg       0.63      0.63      0.63      2000
#      weighted avg       0.62      0.63      0.62      2000
#
# Inference Time: 2.6303 seconds
#
# Alpha: 0.35 - F1 Score: 0.6231, Accuracy: 0.6270, Precision: 0.6233, Recall: 0.6270
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step
# === Classification Report for Alpha: 0.4 ===
#                    precision    recall  f1-score   support
#
#           Airport       0.54      0.64      0.58        74
#          BareLand       0.69      0.76      0.72        62
#     BaseballField       0.89      0.85      0.87        46
#             Beach       0.81      0.85      0.83        61
#            Bridge       0.77      0.77      0.77        75
#            Center       0.61      0.60      0.61        45
#            Church       0.49      0.38      0.43        52
#        Commercial       0.54      0.51      0.52        79
#  DenseResidential       0.49      0.66      0.56        80
#            Desert       0.78      0.79      0.78        48
#          Farmland       0.53      0.43      0.47        70
#            Forest       0.89      0.98      0.94        52
#        Industrial       0.40      0.43      0.42        72
#            Meadow       0.84      0.84      0.84        64
# MediumResidential       0.54      0.49      0.51        59
#          Mountain       0.56      0.48      0.51        73
#              Park       0.64      0.60      0.62        84
#           Parking       0.67      0.79      0.72        61
#        Playground       0.76      0.82      0.79        66
#              Pond       0.89      0.83      0.86        89
#              Port       0.78      0.82      0.80        80
#    RailwayStation       0.46      0.44      0.45        52
#            Resort       0.42      0.44      0.43        54
#             River       0.50      0.68      0.57        71
#            School       0.29      0.22      0.25        64
# SparseResidential       0.79      0.79      0.79        57
#            Square       0.38      0.30      0.34        66
#           Stadium       0.88      0.86      0.87        66
#      StorageTanks       0.58      0.59      0.58        75
#           Viaduct       0.43      0.35      0.39       103
#
#          accuracy                           0.63      2000
#         macro avg       0.63      0.63      0.63      2000
#      weighted avg       0.62      0.63      0.62      2000
#
# Inference Time: 2.5031 seconds
#
# Alpha: 0.4 - F1 Score: 0.6221, Accuracy: 0.6270, Precision: 0.6225, Recall: 0.6270
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step
# === Classification Report for Alpha: 0.45 ===
#                    precision    recall  f1-score   support
#
#           Airport       0.47      0.55      0.51        74
#          BareLand       0.69      0.74      0.71        62
#     BaseballField       0.91      0.89      0.90        46
#             Beach       0.80      0.84      0.82        61
#            Bridge       0.79      0.79      0.79        75
#            Center       0.66      0.64      0.65        45
#            Church       0.49      0.40      0.44        52
#        Commercial       0.51      0.53      0.52        79
#  DenseResidential       0.50      0.66      0.57        80
#            Desert       0.75      0.85      0.80        48
#          Farmland       0.52      0.43      0.47        70
#            Forest       0.89      0.96      0.93        52
#        Industrial       0.39      0.36      0.37        72
#            Meadow       0.82      0.83      0.82        64
# MediumResidential       0.56      0.51      0.53        59
#          Mountain       0.55      0.51      0.53        73
#              Park       0.61      0.55      0.57        84
#           Parking       0.62      0.77      0.69        61
#        Playground       0.72      0.82      0.77        66
#              Pond       0.83      0.83      0.83        89
#              Port       0.81      0.79      0.80        80
#    RailwayStation       0.43      0.37      0.40        52
#            Resort       0.42      0.44      0.43        54
#             River       0.49      0.58      0.53        71
#            School       0.33      0.22      0.26        64
# SparseResidential       0.83      0.77      0.80        57
#            Square       0.34      0.32      0.33        66
#           Stadium       0.88      0.85      0.86        66
#      StorageTanks       0.58      0.60      0.59        75
#           Viaduct       0.44      0.37      0.40       103
#
#          accuracy                           0.62      2000
#         macro avg       0.62      0.63      0.62      2000
#      weighted avg       0.61      0.62      0.61      2000
#
# Inference Time: 2.3820 seconds
#
# Alpha: 0.45 - F1 Score: 0.6131, Accuracy: 0.6180, Precision: 0.6127, Recall: 0.6180
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step
# === Classification Report for Alpha: 0.5 ===
#                    precision    recall  f1-score   support
#
#           Airport       0.51      0.59      0.55        74
#          BareLand       0.69      0.73      0.71        62
#     BaseballField       0.91      0.89      0.90        46
#             Beach       0.81      0.89      0.84        61
#            Bridge       0.76      0.75      0.75        75
#            Center       0.67      0.67      0.67        45
#            Church       0.45      0.35      0.39        52
#        Commercial       0.57      0.46      0.51        79
#  DenseResidential       0.46      0.71      0.56        80
#            Desert       0.75      0.81      0.78        48
#          Farmland       0.52      0.46      0.48        70
#            Forest       0.91      0.94      0.92        52
#        Industrial       0.37      0.46      0.41        72
#            Meadow       0.78      0.84      0.81        64
# MediumResidential       0.57      0.53      0.55        59
#          Mountain       0.57      0.59      0.58        73
#              Park       0.62      0.58      0.60        84
#           Parking       0.68      0.77      0.72        61
#        Playground       0.75      0.77      0.76        66
#              Pond       0.86      0.80      0.83        89
#              Port       0.78      0.81      0.80        80
#    RailwayStation       0.44      0.37      0.40        52
#            Resort       0.43      0.41      0.42        54
#             River       0.50      0.59      0.54        71
#            School       0.32      0.22      0.26        64
# SparseResidential       0.85      0.81      0.83        57
#            Square       0.38      0.32      0.35        66
#           Stadium       0.88      0.88      0.88        66
#      StorageTanks       0.55      0.53      0.54        75
#           Viaduct       0.46      0.37      0.41       103
#
#          accuracy                           0.62      2000
#         macro avg       0.63      0.63      0.63      2000
#      weighted avg       0.62      0.62      0.62      2000
#
# Inference Time: 2.6639 seconds
#
# Alpha: 0.5 - F1 Score: 0.6180, Accuracy: 0.6225, Precision: 0.6198, Recall: 0.6225
