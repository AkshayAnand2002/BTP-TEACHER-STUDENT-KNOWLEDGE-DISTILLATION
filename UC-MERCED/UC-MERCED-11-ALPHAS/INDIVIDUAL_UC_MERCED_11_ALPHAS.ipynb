# %%
# Install the required libraries
# !pip install opendatasets --upgrade --quiet
# !pip install kaggle --quiet

# Import Kaggle and OpenDatasets to download datasets from Kaggle
import opendatasets as od

# Download the dataset from Kaggle
dataset_url = 'https://www.kaggle.com/datasets/abdulhasibuddin/uc-merced-land-use-dataset'
od.download(dataset_url)

import os
import random
import cv2
import numpy as np
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from keras.callbacks import LearningRateScheduler
from keras.optimizers import SGD
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input
from keras.models import Model
import tensorflow as tf

# Set the path to the image folder
data_path = 'uc-merced-land-use-dataset/UCMerced_LandUse/Images'

# Initialize image data and labels
image_data = []
labels = []

# Load the image dataset
for root, dirs, files in os.walk(data_path):
    for file in files:
        if file.endswith(".tif"):
            # Read the image
            image = cv2.imread(os.path.join(root, file))
            image = cv2.resize(image, (128, 128))
            image = img_to_array(image)
            image_data.append(image)

            # Use the folder name as the label
            label = root.split(os.path.sep)[-1]
            labels.append(label)

# Convert to numpy arrays and normalize the images
image_data = np.array(image_data, dtype="float") / 255.0
labels = np.array(labels)

# Binarize the labels
lb = LabelBinarizer()
labels = lb.fit_transform(labels)

# Split the dataset into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(image_data, labels, test_size=0.2, random_state=42)

print(f'Training samples: {len(x_train)}, Testing samples: {len(x_test)}')

# Define the teacher model (more layers)
def teacher_model(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(512, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)

    x = Flatten()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

# Define the student model (fewer layers)
def student_model(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)

    x = Flatten()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

input_shape = (128, 128, 3)
num_classes = len(lb.classes_)

# Build teacher and student models
teacher = teacher_model(input_shape, num_classes)
student = student_model(input_shape, num_classes)

# Define a learning rate scheduler function
# def lr_scheduler(epoch, lr):
#     return lr * tf.math.exp(-0.1) if epoch >= 10 else lr

def lr_scheduler(epoch, lr):
    return float(lr * tf.math.exp(-0.1)) if epoch >= 10 else float(lr)

# Compile and train the teacher model
teacher.compile(optimizer=SGD(learning_rate=1e-2, momentum=0.9), loss='categorical_crossentropy', metrics=['accuracy'])
teacher.fit(x_train, y_train, batch_size=32, epochs=15, validation_data=(x_test, y_test), callbacks=[LearningRateScheduler(lr_scheduler)])

# Precompute teacher's predictions for distillation
teacher_preds = teacher.predict(x_train)

# Define distillation loss function
def distillation_loss(y_true, y_pred, teacher_preds, temperature=3.0, alpha=0.1):
    teacher_batch_preds = tf.gather(teacher_preds, tf.range(tf.shape(y_pred)[0]))
    y_true = tf.keras.activations.softmax(y_true / temperature)
    y_pred = tf.keras.activations.softmax(y_pred / temperature)
    teacher_batch_preds = tf.keras.activations.softmax(teacher_batch_preds / temperature)
    soft_loss = tf.keras.losses.categorical_crossentropy(teacher_batch_preds, y_pred)
    hard_loss = tf.keras.losses.categorical_crossentropy(y_true, y_pred)
    return alpha * soft_loss + (1. - alpha) * hard_loss

# Evaluate models
teacher_score = teacher.evaluate(x_test, y_test, verbose=0)
#student_score = student.evaluate(x_test, y_test, verbose=0)
print(f'Teacher test accuracy: {teacher_score[1] * 100:.2f}%')
#print(f'Student test accuracy: {student_score[1] * 100:.2f}%')
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: akshayanand2002
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/abdulhasibuddin/uc-merced-land-use-dataset
# Downloading uc-merced-land-use-dataset.zip to ./uc-merced-land-use-dataset
# 100%|██████████| 317M/317M [00:03<00:00, 97.1MB/s]
# Training samples: 1680, Testing samples: 420
# Epoch 1/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 282s 5s/step - accuracy: 0.0515 - loss: 3.0483 - val_accuracy: 0.0476 - val_loss: 3.0041 - learning_rate: 0.0100
# Epoch 2/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 282s 5s/step - accuracy: 0.0771 - loss: 2.9646 - val_accuracy: 0.0738 - val_loss: 2.8796 - learning_rate: 0.0100
# Epoch 3/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 317s 5s/step - accuracy: 0.1254 - loss: 2.7884 - val_accuracy: 0.0429 - val_loss: 3.0373 - learning_rate: 0.0100
# Epoch 4/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 329s 5s/step - accuracy: 0.1204 - loss: 2.8574 - val_accuracy: 0.2167 - val_loss: 2.4722 - learning_rate: 0.0100
# Epoch 5/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 279s 5s/step - accuracy: 0.2124 - loss: 2.4783 - val_accuracy: 0.3000 - val_loss: 2.1819 - learning_rate: 0.0100
# Epoch 6/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 328s 5s/step - accuracy: 0.3072 - loss: 2.2256 - val_accuracy: 0.3571 - val_loss: 1.9717 - learning_rate: 0.0100
# Epoch 7/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 315s 5s/step - accuracy: 0.3731 - loss: 1.9570 - val_accuracy: 0.3310 - val_loss: 1.9231 - learning_rate: 0.0100
# Epoch 8/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 285s 5s/step - accuracy: 0.4618 - loss: 1.6914 - val_accuracy: 0.4571 - val_loss: 1.6445 - learning_rate: 0.0100
# Epoch 9/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 316s 5s/step - accuracy: 0.5351 - loss: 1.4840 - val_accuracy: 0.4810 - val_loss: 1.6197 - learning_rate: 0.0100
# Epoch 10/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 320s 5s/step - accuracy: 0.5607 - loss: 1.3898 - val_accuracy: 0.5643 - val_loss: 1.3652 - learning_rate: 0.0100
# Epoch 11/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 280s 5s/step - accuracy: 0.6426 - loss: 1.0852 - val_accuracy: 0.5429 - val_loss: 1.4658 - learning_rate: 0.0090
# Epoch 12/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 320s 5s/step - accuracy: 0.7237 - loss: 0.8334 - val_accuracy: 0.6190 - val_loss: 1.2729 - learning_rate: 0.0082
# Epoch 13/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 324s 5s/step - accuracy: 0.8003 - loss: 0.6469 - val_accuracy: 0.6071 - val_loss: 1.3780 - learning_rate: 0.0074
# Epoch 14/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 322s 5s/step - accuracy: 0.8635 - loss: 0.4594 - val_accuracy: 0.6357 - val_loss: 1.2686 - learning_rate: 0.0067
# Epoch 15/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 320s 5s/step - accuracy: 0.8994 - loss: 0.3300 - val_accuracy: 0.6286 - val_loss: 1.3766 - learning_rate: 0.0061
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 74s 1s/step
# Teacher test accuracy: 62.86%

# %%
# Define distillation loss function
def distillation_loss(y_true, y_pred, teacher_preds, temperature=3.0, alpha=0.1):
    teacher_batch_preds = tf.gather(teacher_preds, tf.range(tf.shape(y_pred)[0]))
    y_true = tf.keras.activations.softmax(y_true / temperature)
    y_pred = tf.keras.activations.softmax(y_pred / temperature)
    teacher_batch_preds = tf.keras.activations.softmax(teacher_batch_preds / temperature)
    soft_loss = tf.keras.losses.categorical_crossentropy(teacher_batch_preds, y_pred)
    hard_loss = tf.keras.losses.categorical_crossentropy(y_true, y_pred)
    return alpha * soft_loss + (1. - alpha) * hard_loss

# Compile and train the student model using distillation loss
student.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3), loss=lambda y_true, y_pred: distillation_loss(y_true, y_pred, teacher_preds), metrics=['accuracy'])
student.fit(x_train, y_train, batch_size=32, epochs=15, validation_data=(x_test, y_test), callbacks=[LearningRateScheduler(lr_scheduler)])

# Evaluate models
teacher_score = teacher.evaluate(x_test, y_test, verbose=0)
student_score = student.evaluate(x_test, y_test, verbose=0)
print(f'Teacher test accuracy: {teacher_score[1] * 100:.2f}%')
print(f'Student test accuracy: {student_score[1] * 100:.2f}%')
# Out:
# Epoch 1/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 102s 2s/step - accuracy: 0.0505 - loss: 3.0445 - val_accuracy: 0.0952 - val_loss: 3.0445 - learning_rate: 0.0010
# Epoch 2/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.0844 - loss: 3.0445 - val_accuracy: 0.1024 - val_loss: 3.0444 - learning_rate: 0.0010
# Epoch 3/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - accuracy: 0.1215 - loss: 3.0444 - val_accuracy: 0.2333 - val_loss: 3.0443 - learning_rate: 0.0010
# Epoch 4/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.2214 - loss: 3.0443 - val_accuracy: 0.3024 - val_loss: 3.0442 - learning_rate: 0.0010
# Epoch 5/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.3160 - loss: 3.0441 - val_accuracy: 0.3357 - val_loss: 3.0440 - learning_rate: 0.0010
# Epoch 6/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.3755 - loss: 3.0440 - val_accuracy: 0.4000 - val_loss: 3.0439 - learning_rate: 0.0010
# Epoch 7/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.4815 - loss: 3.0437 - val_accuracy: 0.5071 - val_loss: 3.0437 - learning_rate: 0.0010
# Epoch 8/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.5499 - loss: 3.0436 - val_accuracy: 0.4952 - val_loss: 3.0437 - learning_rate: 0.0010
# Epoch 9/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.5888 - loss: 3.0434 - val_accuracy: 0.5238 - val_loss: 3.0436 - learning_rate: 0.0010
# Epoch 10/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.6826 - loss: 3.0431 - val_accuracy: 0.5119 - val_loss: 3.0437 - learning_rate: 0.0010
# Epoch 11/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.7536 - loss: 3.0429 - val_accuracy: 0.6214 - val_loss: 3.0433 - learning_rate: 9.0484e-04
# Epoch 12/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.8311 - loss: 3.0427 - val_accuracy: 0.6714 - val_loss: 3.0432 - learning_rate: 8.1873e-04
# Epoch 13/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.8715 - loss: 3.0425 - val_accuracy: 0.6524 - val_loss: 3.0432 - learning_rate: 7.4082e-04
# Epoch 14/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.8781 - loss: 3.0425 - val_accuracy: 0.6857 - val_loss: 3.0432 - learning_rate: 6.7032e-04
# Epoch 15/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9166 - loss: 3.0424 - val_accuracy: 0.6357 - val_loss: 3.0433 - learning_rate: 6.0653e-04
# Teacher test accuracy: 62.86%
# Student test accuracy: 63.57%

# %%
# Evaluate and print additional metrics for teacher and student models
from sklearn.metrics import classification_report
import time

def evaluate_model(model, x_test, y_test):
    # Predict the labels
    start_time = time.time()
    y_pred_probs = model.predict(x_test)
    inference_time = time.time() - start_time

    # Get the predicted classes
    y_pred = np.argmax(y_pred_probs, axis=1)
    y_true = np.argmax(y_test, axis=1)

    # Calculate precision, recall, F1 score
    report = classification_report(y_true, y_pred, target_names=lb.classes_)

    # Print the metrics
    print(report)
    print(f"Inference Time: {inference_time:.4f} seconds")
    return y_pred_probs

print("=== Teacher Model Evaluation ===")
teacher_pred_probs = evaluate_model(teacher, x_test, y_test)

print("\n=== Student Model Evaluation ===")
student_pred_probs = evaluate_model(student, x_test, y_test)
# Out:
# === Teacher Model Evaluation ===
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step
#                    precision    recall  f1-score   support
#
#      agricultural       0.88      0.81      0.84        26
#          airplane       0.83      0.77      0.80        26
#   baseballdiamond       0.76      0.96      0.85        23
#             beach       0.74      1.00      0.85        14
#         buildings       0.32      0.53      0.40        15
#         chaparral       1.00      0.96      0.98        23
#  denseresidential       0.36      0.47      0.41        17
#            forest       0.83      0.88      0.86        17
#           freeway       0.36      0.56      0.44        16
#        golfcourse       0.44      0.78      0.56        18
#            harbor       0.93      0.59      0.72        22
#      intersection       0.59      0.37      0.45        27
# mediumresidential       0.33      0.42      0.37        24
#    mobilehomepark       0.75      0.33      0.46        18
#          overpass       0.69      0.50      0.58        18
#        parkinglot       0.78      0.70      0.74        20
#             river       0.63      0.60      0.62        20
#            runway       0.87      0.62      0.72        21
# sparseresidential       0.59      0.65      0.62        20
#      storagetanks       0.50      0.33      0.40        18
#       tenniscourt       0.42      0.29      0.34        17
#
#          accuracy                           0.63       420
#         macro avg       0.65      0.62      0.62       420
#      weighted avg       0.66      0.63      0.63       420
#
# Inference Time: 31.9820 seconds
#
# === Student Model Evaluation ===
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 11s 760ms/step
#                    precision    recall  f1-score   support
#
#      agricultural       0.76      0.85      0.80        26
#          airplane       0.68      0.73      0.70        26
#   baseballdiamond       0.83      0.83      0.83        23
#             beach       0.78      1.00      0.88        14
#         buildings       0.36      0.53      0.43        15
#         chaparral       1.00      1.00      1.00        23
#  denseresidential       0.27      0.24      0.25        17
#            forest       1.00      0.65      0.79        17
#           freeway       0.50      0.44      0.47        16
#        golfcourse       0.79      0.61      0.69        18
#            harbor       0.77      0.77      0.77        22
#      intersection       0.93      0.52      0.67        27
# mediumresidential       0.36      0.17      0.23        24
#    mobilehomepark       0.35      0.83      0.49        18
#          overpass       0.58      0.83      0.68        18
#        parkinglot       0.89      0.40      0.55        20
#             river       0.83      0.75      0.79        20
#            runway       0.92      0.57      0.71        21
# sparseresidential       0.65      0.65      0.65        20
#      storagetanks       0.39      0.39      0.39        18
#       tenniscourt       0.32      0.53      0.40        17
#
#          accuracy                           0.64       420
#         macro avg       0.66      0.63      0.63       420
#      weighted avg       0.68      0.64      0.64       420
#
# Inference Time: 11.0276 seconds

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score, classification_report
import time

# Define alpha values for experiments
alpha_values = [0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
f1_scores = []
accuracies = []
precisions = []
recalls = []
inference_times = []

# Function to evaluate F1-score, accuracy, precision, recall, and inference time for a given model and alpha
def evaluate_student_with_alpha(alpha):
    # Redefine distillation loss function with current alpha
    def distillation_loss(y_true, y_pred, teacher_preds, temperature=3.0, alpha=alpha):
        teacher_batch_preds = tf.gather(teacher_preds, tf.range(tf.shape(y_pred)[0]))
        y_true = tf.keras.activations.softmax(y_true / temperature)
        y_pred = tf.keras.activations.softmax(y_pred / temperature)
        teacher_batch_preds = tf.keras.activations.softmax(teacher_batch_preds / temperature)
        soft_loss = tf.keras.losses.categorical_crossentropy(teacher_batch_preds, y_pred)
        hard_loss = tf.keras.losses.categorical_crossentropy(y_true, y_pred)
        return alpha * soft_loss + (1. - alpha) * hard_loss

    # Compile the student model with the new distillation loss
    student.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
                    loss=lambda y_true, y_pred: distillation_loss(y_true, y_pred, teacher_preds),
                    metrics=['accuracy'])

    # Train the student model
    student.fit(x_train, y_train, batch_size=32, epochs=15, validation_data=(x_test, y_test),
                callbacks=[LearningRateScheduler(lr_scheduler)], verbose=0)

    # Predict and evaluate
    start_time = time.time()
    y_pred_probs = student.predict(x_test)
    inference_time = time.time() - start_time
    y_pred = np.argmax(y_pred_probs, axis=1)
    y_true = np.argmax(y_test, axis=1)

    # Calculate and store F1-score, accuracy, precision, recall, and inference time
    f1 = f1_score(y_true, y_pred, average='weighted')
    acc = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted')
    recall = recall_score(y_true, y_pred, average='weighted')

    # Append the results
    f1_scores.append(f1)
    accuracies.append(acc)
    precisions.append(precision)
    recalls.append(recall)
    inference_times.append(inference_time)

    # Print classification report
    print(f"=== Classification Report for Alpha: {alpha} ===")
    print(classification_report(y_true, y_pred, target_names=lb.classes_))
    print(f"Inference Time: {inference_time:.4f} seconds\n")
    print(f"Alpha: {alpha} - F1 Score: {f1:.4f}, Accuracy: {acc:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}")

# Run evaluation for each alpha
for alpha in alpha_values:
    evaluate_student_with_alpha(alpha)

# Plot F1-Score vs. Alpha
plt.figure(figsize=(7, 5))
plt.plot(alpha_values, f1_scores, marker='o', color='b')
plt.xlabel("Alpha Values")
plt.ylabel("F1-Score Of Student Model")
plt.grid(True)
plt.savefig("f1_score_vs_alpha.pdf")
plt.show()

# Plot Accuracy vs. Alpha
plt.figure(figsize=(7, 5))
plt.plot(alpha_values, accuracies, marker='o', color='g')
plt.xlabel("Alpha Values")
plt.ylabel("Accuracy Of Student Model")
plt.grid(True)
plt.savefig("accuracy_vs_alpha.pdf")
plt.show()

# Plot Precision vs. Alpha
plt.figure(figsize=(7, 5))
plt.plot(alpha_values, precisions, marker='o', color='orange')
plt.xlabel("Alpha Values")
plt.ylabel("Precision Of Student Model")
plt.grid(True)
plt.savefig("precision_vs_alpha.pdf")
plt.show()

# Plot Recall vs. Alpha
plt.figure(figsize=(7, 5))
plt.plot(alpha_values, recalls, marker='o', color='red')
plt.xlabel("Alpha Values")
plt.ylabel("Recall Of Student Model")
plt.grid(True)
plt.savefig("recall_vs_alpha.pdf")
plt.show()

# Plot Inference Time vs. Alpha
plt.figure(figsize=(7, 5))
plt.plot(alpha_values, inference_times, marker='o', color='purple')
plt.xlabel("Alpha Values")
plt.ylabel("Inference Time Of Student Model (in seconds)")
plt.grid(True)
plt.savefig("inference_time_vs_alpha.pdf")
plt.show()
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 464ms/step
# === Classification Report for Alpha: 0.0 ===
#                    precision    recall  f1-score   support
#
#      agricultural       0.93      0.96      0.94        26
#          airplane       0.78      0.81      0.79        26
#   baseballdiamond       0.71      0.87      0.78        23
#             beach       0.93      1.00      0.97        14
#         buildings       0.38      0.67      0.49        15
#         chaparral       0.96      1.00      0.98        23
#  denseresidential       0.30      0.35      0.32        17
#            forest       0.83      0.88      0.86        17
#           freeway       0.67      0.62      0.65        16
#        golfcourse       0.62      0.72      0.67        18
#            harbor       0.85      0.77      0.81        22
#      intersection       0.75      0.67      0.71        27
# mediumresidential       0.44      0.33      0.38        24
#    mobilehomepark       0.60      0.33      0.43        18
#          overpass       0.70      0.89      0.78        18
#        parkinglot       0.83      0.75      0.79        20
#             river       0.75      0.90      0.82        20
#            runway       0.74      0.67      0.70        21
# sparseresidential       0.60      0.75      0.67        20
#      storagetanks       0.44      0.22      0.30        18
#       tenniscourt       0.44      0.24      0.31        17
#
#          accuracy                           0.70       420
#         macro avg       0.68      0.69      0.67       420
#      weighted avg       0.69      0.70      0.68       420
#
# Inference Time: 6.7569 seconds
#
# Alpha: 0.0 - F1 Score: 0.6844, Accuracy: 0.6952, Precision: 0.6912, Recall: 0.6952
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 5s 315ms/step
# === Classification Report for Alpha: 0.05 ===
#                    precision    recall  f1-score   support
#
#      agricultural       0.95      0.81      0.88        26
#          airplane       0.70      0.81      0.75        26
#   baseballdiamond       0.77      0.87      0.82        23
#             beach       0.78      1.00      0.88        14
#         buildings       0.43      0.60      0.50        15
#         chaparral       0.82      1.00      0.90        23
#  denseresidential       0.27      0.41      0.33        17
#            forest       0.89      0.94      0.91        17
#           freeway       0.67      0.50      0.57        16
#        golfcourse       0.72      0.72      0.72        18
#            harbor       0.78      0.82      0.80        22
#      intersection       0.83      0.70      0.76        27
# mediumresidential       0.43      0.25      0.32        24
#    mobilehomepark       0.60      0.33      0.43        18
#          overpass       0.67      0.89      0.76        18
#        parkinglot       0.93      0.65      0.76        20
#             river       0.71      0.85      0.77        20
#            runway       0.74      0.81      0.77        21
# sparseresidential       0.69      0.55      0.61        20
#      storagetanks       0.67      0.44      0.53        18
#       tenniscourt       0.44      0.47      0.46        17
#
#          accuracy                           0.69       420
#         macro avg       0.69      0.69      0.68       420
#      weighted avg       0.70      0.69      0.69       420
#
# Inference Time: 5.3309 seconds
#
# Alpha: 0.05 - F1 Score: 0.6868, Accuracy: 0.6929, Precision: 0.7011, Recall: 0.6929
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 313ms/step
# === Classification Report for Alpha: 0.1 ===
#                    precision    recall  f1-score   support
#
#      agricultural       1.00      0.85      0.92        26
#          airplane       0.86      0.73      0.79        26
#   baseballdiamond       0.88      0.91      0.89        23
#             beach       0.82      1.00      0.90        14
#         buildings       0.56      0.60      0.58        15
#         chaparral       0.85      1.00      0.92        23
#  denseresidential       0.33      0.35      0.34        17
#            forest       0.94      0.88      0.91        17
#           freeway       0.50      0.75      0.60        16
#        golfcourse       0.81      0.72      0.76        18
#            harbor       0.86      0.82      0.84        22
#      intersection       0.88      0.56      0.68        27
# mediumresidential       0.50      0.21      0.29        24
#    mobilehomepark       0.50      0.83      0.62        18
#          overpass       0.71      0.83      0.77        18
#        parkinglot       0.71      0.85      0.77        20
#             river       0.85      0.85      0.85        20
#            runway       0.61      0.81      0.69        21
# sparseresidential       0.65      0.55      0.59        20
#      storagetanks       0.56      0.50      0.53        18
#       tenniscourt       0.50      0.41      0.45        17
#
#          accuracy                           0.71       420
#         macro avg       0.71      0.72      0.70       420
#      weighted avg       0.72      0.71      0.71       420
#
# Inference Time: 4.7398 seconds
#
# Alpha: 0.1 - F1 Score: 0.7077, Accuracy: 0.7143, Precision: 0.7247, Recall: 0.7143
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 5s 314ms/step
# === Classification Report for Alpha: 0.15 ===
#                    precision    recall  f1-score   support
#
#      agricultural       0.96      0.96      0.96        26
#          airplane       0.81      0.81      0.81        26
#   baseballdiamond       0.80      0.87      0.83        23
#             beach       0.93      1.00      0.97        14
#         buildings       0.39      0.47      0.42        15
#         chaparral       1.00      1.00      1.00        23
#  denseresidential       0.26      0.47      0.33        17
#            forest       1.00      0.88      0.94        17
#           freeway       0.65      0.69      0.67        16
#        golfcourse       0.84      0.89      0.86        18
#            harbor       0.82      0.82      0.82        22
#      intersection       0.78      0.67      0.72        27
# mediumresidential       0.50      0.25      0.33        24
#    mobilehomepark       0.48      0.56      0.51        18
#          overpass       0.62      0.83      0.71        18
#        parkinglot       0.78      0.70      0.74        20
#             river       0.83      0.75      0.79        20
#            runway       0.71      0.81      0.76        21
# sparseresidential       0.73      0.55      0.63        20
#      storagetanks       0.50      0.39      0.44        18
#       tenniscourt       0.43      0.35      0.39        17
#
#          accuracy                           0.71       420
#         macro avg       0.71      0.70      0.70       420
#      weighted avg       0.72      0.71      0.71       420
#
# Inference Time: 5.4200 seconds
#
# Alpha: 0.15 - F1 Score: 0.7067, Accuracy: 0.7071, Precision: 0.7195, Recall: 0.7071
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 5s 321ms/step
# === Classification Report for Alpha: 0.2 ===
#                    precision    recall  f1-score   support
#
#      agricultural       0.90      1.00      0.95        26
#          airplane       0.72      0.69      0.71        26
#   baseballdiamond       0.95      0.91      0.93        23
#             beach       0.88      1.00      0.93        14
#         buildings       0.47      0.60      0.53        15
#         chaparral       1.00      0.96      0.98        23
#  denseresidential       0.26      0.29      0.28        17
#            forest       1.00      0.88      0.94        17
#           freeway       0.75      0.38      0.50        16
#        golfcourse       0.71      0.83      0.77        18
#            harbor       0.76      0.73      0.74        22
#      intersection       0.89      0.63      0.74        27
# mediumresidential       0.57      0.33      0.42        24
#    mobilehomepark       0.35      0.61      0.45        18
#          overpass       0.57      0.89      0.70        18
#        parkinglot       1.00      0.50      0.67        20
#             river       0.89      0.85      0.87        20
#            runway       0.65      0.81      0.72        21
# sparseresidential       0.69      0.55      0.61        20
#      storagetanks       0.36      0.50      0.42        18
#       tenniscourt       0.60      0.53      0.56        17
#
#          accuracy                           0.70       420
#         macro avg       0.71      0.69      0.69       420
#      weighted avg       0.73      0.70      0.70       420
#
# Inference Time: 4.8676 seconds
#
# Alpha: 0.2 - F1 Score: 0.6970, Accuracy: 0.6952, Precision: 0.7287, Recall: 0.6952
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 5s 323ms/step
# === Classification Report for Alpha: 0.25 ===
#                    precision    recall  f1-score   support
#
#      agricultural       0.90      1.00      0.95        26
#          airplane       0.73      0.73      0.73        26
#   baseballdiamond       0.87      0.87      0.87        23
#             beach       0.88      1.00      0.93        14
#         buildings       0.59      0.67      0.62        15
#         chaparral       1.00      1.00      1.00        23
#  denseresidential       0.27      0.47      0.34        17
#            forest       1.00      0.94      0.97        17
#           freeway       0.57      0.50      0.53        16
#        golfcourse       0.64      0.78      0.70        18
#            harbor       0.86      0.82      0.84        22
#      intersection       0.79      0.81      0.80        27
# mediumresidential       0.36      0.17      0.23        24
#    mobilehomepark       0.59      0.56      0.57        18
#          overpass       0.94      0.83      0.88        18
#        parkinglot       0.93      0.65      0.76        20
#             river       0.94      0.85      0.89        20
#            runway       0.83      0.71      0.77        21
# sparseresidential       0.65      0.65      0.65        20
#      storagetanks       0.53      0.50      0.51        18
#       tenniscourt       0.38      0.53      0.44        17
#
#          accuracy                           0.72       420
#         macro avg       0.73      0.72      0.71       420
#      weighted avg       0.73      0.72      0.72       420
#
# Inference Time: 5.4243 seconds
#
# Alpha: 0.25 - F1 Score: 0.7218, Accuracy: 0.7214, Precision: 0.7349, Recall: 0.7214
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 420ms/step
# === Classification Report for Alpha: 0.3 ===
#                    precision    recall  f1-score   support
#
#      agricultural       0.96      1.00      0.98        26
#          airplane       0.82      0.69      0.75        26
#   baseballdiamond       0.95      0.91      0.93        23
#             beach       0.88      1.00      0.93        14
#         buildings       0.56      0.67      0.61        15
#         chaparral       0.96      1.00      0.98        23
#  denseresidential       0.30      0.53      0.38        17
#            forest       1.00      0.94      0.97        17
#           freeway       0.69      0.56      0.62        16
#        golfcourse       0.68      0.83      0.75        18
#            harbor       0.82      0.82      0.82        22
#      intersection       0.90      0.67      0.77        27
# mediumresidential       0.50      0.12      0.20        24
#    mobilehomepark       0.79      0.61      0.69        18
#          overpass       0.82      0.78      0.80        18
#        parkinglot       0.87      0.65      0.74        20
#             river       0.94      0.80      0.86        20
#            runway       0.79      0.71      0.75        21
# sparseresidential       0.52      0.55      0.54        20
#      storagetanks       0.67      0.44      0.53        18
#       tenniscourt       0.28      0.76      0.41        17
#
#          accuracy                           0.72       420
#         macro avg       0.75      0.72      0.71       420
#      weighted avg       0.76      0.72      0.72       420
#
# Inference Time: 6.3354 seconds
#
# Alpha: 0.3 - F1 Score: 0.7214, Accuracy: 0.7167, Precision: 0.7608, Recall: 0.7167
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 5s 318ms/step
# === Classification Report for Alpha: 0.35 ===
#                    precision    recall  f1-score   support
#
#      agricultural       1.00      0.92      0.96        26
#          airplane       0.93      0.54      0.68        26
#   baseballdiamond       0.95      0.91      0.93        23
#             beach       0.93      1.00      0.97        14
#         buildings       0.64      0.47      0.54        15
#         chaparral       0.96      1.00      0.98        23
#  denseresidential       0.33      0.41      0.37        17
#            forest       1.00      0.94      0.97        17
#           freeway       0.73      0.69      0.71        16
#        golfcourse       0.53      0.89      0.67        18
#            harbor       0.94      0.73      0.82        22
#      intersection       0.84      0.59      0.70        27
# mediumresidential       0.67      0.08      0.15        24
#    mobilehomepark       0.71      0.67      0.69        18
#          overpass       0.93      0.72      0.81        18
#        parkinglot       1.00      0.70      0.82        20
#             river       0.93      0.70      0.80        20
#            runway       0.88      0.67      0.76        21
# sparseresidential       0.52      0.65      0.58        20
#      storagetanks       0.70      0.39      0.50        18
#       tenniscourt       0.17      0.76      0.28        17
#
#          accuracy                           0.68       420
#         macro avg       0.78      0.69      0.70       420
#      weighted avg       0.79      0.68      0.70       420
#
# Inference Time: 4.7838 seconds
#
# Alpha: 0.35 - F1 Score: 0.7033, Accuracy: 0.6833, Precision: 0.7920, Recall: 0.6833
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 5s 316ms/step
# === Classification Report for Alpha: 0.4 ===
#                    precision    recall  f1-score   support
#
#      agricultural       1.00      0.88      0.94        26
#          airplane       0.94      0.62      0.74        26
#   baseballdiamond       0.88      0.91      0.89        23
#             beach       0.88      1.00      0.93        14
#         buildings       0.58      0.47      0.52        15
#         chaparral       0.92      1.00      0.96        23
#  denseresidential       0.32      0.41      0.36        17
#            forest       1.00      0.88      0.94        17
#           freeway       0.58      0.44      0.50        16
#        golfcourse       0.48      0.89      0.63        18
#            harbor       0.94      0.68      0.79        22
#      intersection       0.92      0.44      0.60        27
# mediumresidential       0.60      0.25      0.35        24
#    mobilehomepark       0.73      0.44      0.55        18
#          overpass       0.87      0.72      0.79        18
#        parkinglot       1.00      0.75      0.86        20
#             river       0.91      0.50      0.65        20
#            runway       0.85      0.81      0.83        21
# sparseresidential       0.43      0.60      0.50        20
#      storagetanks       0.70      0.39      0.50        18
#       tenniscourt       0.18      0.76      0.29        17
#
#          accuracy                           0.66       420
#         macro avg       0.75      0.66      0.67       420
#      weighted avg       0.77      0.66      0.68       420
#
# Inference Time: 5.3585 seconds
#
# Alpha: 0.4 - F1 Score: 0.6812, Accuracy: 0.6595, Precision: 0.7670, Recall: 0.6595
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 5s 340ms/step
# === Classification Report for Alpha: 0.45 ===
#                    precision    recall  f1-score   support
#
#      agricultural       1.00      0.88      0.94        26
#          airplane       0.94      0.58      0.71        26
#   baseballdiamond       0.91      0.91      0.91        23
#             beach       1.00      1.00      1.00        14
#         buildings       0.75      0.40      0.52        15
#         chaparral       0.88      1.00      0.94        23
#  denseresidential       0.26      0.53      0.35        17
#            forest       0.94      0.94      0.94        17
#           freeway       0.76      0.81      0.79        16
#        golfcourse       0.62      0.83      0.71        18
#            harbor       0.94      0.77      0.85        22
#      intersection       1.00      0.30      0.46        27
# mediumresidential       0.55      0.25      0.34        24
#    mobilehomepark       0.88      0.39      0.54        18
#          overpass       1.00      0.61      0.76        18
#        parkinglot       1.00      0.70      0.82        20
#             river       0.92      0.60      0.73        20
#            runway       0.94      0.71      0.81        21
# sparseresidential       0.40      0.60      0.48        20
#      storagetanks       1.00      0.28      0.43        18
#       tenniscourt       0.13      0.65      0.22        17
#
#          accuracy                           0.65       420
#         macro avg       0.80      0.65      0.68       420
#      weighted avg       0.81      0.65      0.68       420
#
# Inference Time: 5.3306 seconds
#
# Alpha: 0.45 - F1 Score: 0.6825, Accuracy: 0.6500, Precision: 0.8142, Recall: 0.6500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 5s 319ms/step
# === Classification Report for Alpha: 0.5 ===
#                    precision    recall  f1-score   support
#
#      agricultural       0.96      0.96      0.96        26
#          airplane       1.00      0.50      0.67        26
#   baseballdiamond       0.91      0.87      0.89        23
#             beach       1.00      1.00      1.00        14
#         buildings       0.64      0.47      0.54        15
#         chaparral       1.00      1.00      1.00        23
#  denseresidential       0.25      0.53      0.34        17
#            forest       1.00      0.94      0.97        17
#           freeway       0.64      0.56      0.60        16
#        golfcourse       0.31      0.94      0.47        18
#            harbor       0.89      0.73      0.80        22
#      intersection       1.00      0.30      0.46        27
# mediumresidential       0.31      0.17      0.22        24
#    mobilehomepark       0.89      0.44      0.59        18
#          overpass       0.92      0.67      0.77        18
#        parkinglot       1.00      0.50      0.67        20
#             river       1.00      0.50      0.67        20
#            runway       0.82      0.86      0.84        21
# sparseresidential       0.42      0.55      0.48        20
#      storagetanks       0.83      0.28      0.42        18
#       tenniscourt       0.20      0.65      0.31        17
#
#          accuracy                           0.63       420
#         macro avg       0.76      0.64      0.65       420
#      weighted avg       0.78      0.63      0.65       420
#
# Inference Time: 5.3298 seconds
#
# Alpha: 0.5 - F1 Score: 0.6532, Accuracy: 0.6333, Precision: 0.7766, Recall: 0.6333
