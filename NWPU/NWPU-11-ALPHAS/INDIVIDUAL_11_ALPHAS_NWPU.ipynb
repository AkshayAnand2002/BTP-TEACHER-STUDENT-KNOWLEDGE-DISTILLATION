# %%
# Install required libraries
# !pip install opendatasets --upgrade --quiet
# !pip install kaggle --quiet

# Import libraries for downloading the dataset
import opendatasets as od
import os
import random
import cv2
import numpy as np
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from keras.callbacks import LearningRateScheduler
from keras.optimizers import SGD
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input
from keras.models import Model
import tensorflow as tf
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score, classification_report
import time

# Download dataset from Kaggle
dataset_url = 'https://www.kaggle.com/datasets/punfake/resisc45'
od.download(dataset_url)

# Set the path to the image folder
data_path = 'resisc45/NWPU-RESISC45'

# Initialize image data and labels
image_data = []
labels = []

# Load the image dataset
for root, dirs, files in os.walk(data_path):
    for file in files:
        if file.endswith(".jpg"):
            # Read the image
            image = cv2.imread(os.path.join(root, file))
            image = cv2.resize(image, (32, 32))  # Resize
            image = img_to_array(image)
            image_data.append(image)

            # Use the folder name as the label
            label = root.split(os.path.sep)[-1]
            labels.append(label)

# Convert to numpy arrays and normalize the images
image_data = np.array(image_data, dtype="float") / 255.0
labels = np.array(labels)

# Binarize the labels
lb = LabelBinarizer()
labels = lb.fit_transform(labels)

# Split the dataset into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(image_data, labels, test_size=0.2, random_state=42)

print(f'Training samples: {len(x_train)}, Testing samples: {len(x_test)}')

# Define the teacher model (more layers)
def teacher_model(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(512, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)

    x = Flatten()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

# Define the student model (fewer layers)
def student_model(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)

    x = Flatten()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

input_shape = (32, 32, 3)  # Updated input shape
num_classes = len(lb.classes_)

# Build teacher and student models
teacher = teacher_model(input_shape, num_classes)
student = student_model(input_shape, num_classes)

# Define a learning rate scheduler function
def lr_scheduler(epoch, lr):
    return float(lr * tf.math.exp(-0.1)) if epoch >= 10 else float(lr)

# Compile and train the teacher model
teacher.compile(optimizer=SGD(learning_rate=1e-2, momentum=0.9), loss='categorical_crossentropy', metrics=['accuracy'])
teacher.fit(x_train, y_train, batch_size=32, epochs=8, validation_data=(x_test, y_test), callbacks=[LearningRateScheduler(lr_scheduler)])

# Precompute teacher's predictions for distillation
teacher_preds = teacher.predict(x_train)

# Define distillation loss function
def distillation_loss(y_true, y_pred, teacher_preds, temperature=3.0, alpha=0.1):
    teacher_batch_preds = tf.gather(teacher_preds, tf.range(tf.shape(y_pred)[0]))
    y_true = tf.keras.activations.softmax(y_true / temperature)
    y_pred = tf.keras.activations.softmax(y_pred / temperature)
    teacher_batch_preds = tf.keras.activations.softmax(teacher_batch_preds / temperature)
    soft_loss = tf.keras.losses.categorical_crossentropy(teacher_batch_preds, y_pred)
    hard_loss = tf.keras.losses.categorical_crossentropy(y_true, y_pred)
    return alpha * soft_loss + (1. - alpha) * hard_loss
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: akshayanand2002
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/punfake/resisc45
# Downloading resisc45.zip to ./resisc45
# 100%|██████████| 407M/407M [00:07<00:00, 58.6MB/s]
# Training samples: 25200, Testing samples: 6300
# Epoch 1/8
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 279s 353ms/step - accuracy: 0.0459 - loss: 3.6755 - val_accuracy: 0.1257 - val_loss: 3.2392 - learning_rate: 0.0100
# Epoch 2/8
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 319s 349ms/step - accuracy: 0.1631 - loss: 3.0442 - val_accuracy: 0.2635 - val_loss: 2.5879 - learning_rate: 0.0100
# Epoch 3/8
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 324s 353ms/step - accuracy: 0.2726 - loss: 2.5591 - val_accuracy: 0.3813 - val_loss: 2.1696 - learning_rate: 0.0100
# Epoch 4/8
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 319s 349ms/step - accuracy: 0.3636 - loss: 2.2173 - val_accuracy: 0.4244 - val_loss: 1.9927 - learning_rate: 0.0100
# Epoch 5/8
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 322s 349ms/step - accuracy: 0.4320 - loss: 1.9610 - val_accuracy: 0.4702 - val_loss: 1.8077 - learning_rate: 0.0100
# Epoch 6/8
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 323s 350ms/step - accuracy: 0.4951 - loss: 1.7098 - val_accuracy: 0.4983 - val_loss: 1.7051 - learning_rate: 0.0100
# Epoch 7/8
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 323s 351ms/step - accuracy: 0.5522 - loss: 1.5099 - val_accuracy: 0.5414 - val_loss: 1.5657 - learning_rate: 0.0100
# Epoch 8/8
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 324s 354ms/step - accuracy: 0.6051 - loss: 1.3084 - val_accuracy: 0.6002 - val_loss: 1.3890 - learning_rate: 0.0100
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 66s 84ms/step

# %%
teacher_score = teacher.evaluate(x_test, y_test, verbose=0)
print(f'Teacher test accuracy: {teacher_score[1] * 100:.2f}%')
# Out:
# Teacher test accuracy: 60.02%

# %%
student.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3), loss=lambda y_true, y_pred: distillation_loss(y_true, y_pred, teacher_preds), metrics=['accuracy'])
student.fit(x_train, y_train, batch_size=32, epochs=10, validation_data=(x_test, y_test), callbacks=[LearningRateScheduler(lr_scheduler)])
# Out:
# Epoch 1/10
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 72s 86ms/step - accuracy: 0.0411 - loss: 3.8067 - val_accuracy: 0.1435 - val_loss: 3.8066 - learning_rate: 0.0010
# Epoch 2/10
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 81s 85ms/step - accuracy: 0.1542 - loss: 3.8066 - val_accuracy: 0.2659 - val_loss: 3.8065 - learning_rate: 0.0010
# Epoch 3/10
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 64s 81ms/step - accuracy: 0.2662 - loss: 3.8065 - val_accuracy: 0.3576 - val_loss: 3.8064 - learning_rate: 0.0010
# Epoch 4/10
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 82s 81ms/step - accuracy: 0.3560 - loss: 3.8064 - val_accuracy: 0.4005 - val_loss: 3.8063 - learning_rate: 0.0010
# Epoch 5/10
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 66s 83ms/step - accuracy: 0.3944 - loss: 3.8063 - val_accuracy: 0.4549 - val_loss: 3.8063 - learning_rate: 0.0010
# Epoch 6/10
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 82s 83ms/step - accuracy: 0.4504 - loss: 3.8063 - val_accuracy: 0.4817 - val_loss: 3.8062 - learning_rate: 0.0010
# Epoch 7/10
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 63s 80ms/step - accuracy: 0.4830 - loss: 3.8062 - val_accuracy: 0.4994 - val_loss: 3.8062 - learning_rate: 0.0010
# Epoch 8/10
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 65s 83ms/step - accuracy: 0.5196 - loss: 3.8062 - val_accuracy: 0.4959 - val_loss: 3.8062 - learning_rate: 0.0010
# Epoch 9/10
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 65s 82ms/step - accuracy: 0.5391 - loss: 3.8062 - val_accuracy: 0.5187 - val_loss: 3.8062 - learning_rate: 0.0010
# Epoch 10/10
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 64s 81ms/step - accuracy: 0.5677 - loss: 3.8061 - val_accuracy: 0.5457 - val_loss: 3.8062 - learning_rate: 0.0010

# %%
# Evaluate models
#teacher_score = teacher.evaluate(x_test, y_test, verbose=0)
student_score = student.evaluate(x_test, y_test, verbose=0)
#print(f'Teacher test accuracy: {teacher_score[1] * 100:.2f}%')
print(f'Student test accuracy: {student_score[1] * 100:.2f}%')
# Out:
# Student test accuracy: 54.57%

# %%
# Evaluate the teacher model
teacher_score = teacher.evaluate(x_test, y_test, verbose=0)

print(f'Teacher test accuracy: {teacher_score[1] * 100:.2f}%')

# Generate predictions from the teacher model
teacher_preds_probs = teacher.predict(x_test)
teacher_preds = np.argmax(teacher_preds_probs, axis=1)
y_true = np.argmax(y_test, axis=1)

# Print the classification report for the teacher model
print("=== Teacher Model Classification Report ===")
print(classification_report(y_true, teacher_preds, target_names=lb.classes_))
# Out:
# Teacher test accuracy: 60.02%
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 16s 80ms/step
# === Teacher Model Classification Report ===
#                        precision    recall  f1-score   support
#
#              airplane       0.56      0.70      0.62       142
#               airport       0.60      0.41      0.49       136
#      baseball_diamond       0.80      0.52      0.63       151
#      basketball_court       0.40      0.24      0.30       147
#                 beach       0.62      0.78      0.69       138
#                bridge       0.66      0.77      0.71       137
#             chaparral       0.90      0.87      0.88       122
#                church       0.60      0.42      0.49       171
#     circular_farmland       0.69      0.73      0.71       141
#                 cloud       0.82      0.78      0.80       157
#       commercial_area       0.48      0.42      0.45       154
#     dense_residential       0.53      0.69      0.60       153
#                desert       0.85      0.78      0.81       158
#                forest       0.79      0.85      0.82       127
#               freeway       0.46      0.51      0.49       135
#           golf_course       0.76      0.66      0.71       137
#    ground_track_field       0.57      0.65      0.60       147
#                harbor       0.86      0.74      0.80       137
#       industrial_area       0.57      0.54      0.56       138
#          intersection       0.64      0.50      0.56       140
#                island       0.85      0.90      0.88       142
#                  lake       0.80      0.83      0.82       151
#                meadow       0.69      0.93      0.79       142
#    medium_residential       0.38      0.69      0.49       124
#      mobile_home_park       0.58      0.57      0.58       124
#              mountain       0.52      0.51      0.51       141
#              overpass       0.60      0.58      0.59       130
#                palace       0.38      0.24      0.29       139
#           parking_lot       0.84      0.54      0.66       142
#               railway       0.35      0.53      0.42       141
#       railway_station       0.44      0.28      0.34       150
#  rectangular_farmland       0.46      0.45      0.46       138
#                 river       0.69      0.41      0.51       115
#            roundabout       0.33      0.30      0.31       144
#                runway       0.49      0.56      0.52       119
#               sea_ice       0.75      0.88      0.81       134
#                  ship       0.42      0.62      0.50       135
#              snowberg       0.68      0.82      0.74       152
#    sparse_residential       0.64      0.76      0.70       144
#               stadium       0.61      0.77      0.68       138
#          storage_tank       0.52      0.60      0.56       129
#          tennis_court       0.56      0.20      0.29       147
#               terrace       0.61      0.52      0.56       146
# thermal_power_station       0.38      0.54      0.44       138
#               wetland       0.70      0.46      0.55       127
#
#              accuracy                           0.60      6300
#             macro avg       0.61      0.60      0.59      6300
#          weighted avg       0.61      0.60      0.59      6300

# %%
#alpha_values = [0.01, 0.1, 0.2, 0.3, 0.4]
alpha_values = [0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
f1_scores = []
accuracies = []
precisions = []
recalls = []
inference_times = []

teacher_preds = teacher.predict(x_train)

# Function to evaluate F1-score, accuracy, precision, recall, and inference time for a given model and alpha
def evaluate_student_with_alpha(alpha):
    # Redefine distillation loss function with current alpha
    def distillation_loss(y_true, y_pred, teacher_preds, temperature=3.0, alpha=alpha):
        teacher_batch_preds = tf.gather(teacher_preds, tf.range(tf.shape(y_pred)[0]))
        y_true = tf.keras.activations.softmax(y_true / temperature)
        y_pred = tf.keras.activations.softmax(y_pred / temperature)
        teacher_batch_preds = tf.keras.activations.softmax(teacher_batch_preds / temperature)
        soft_loss = tf.keras.losses.categorical_crossentropy(teacher_batch_preds, y_pred)
        hard_loss = tf.keras.losses.categorical_crossentropy(y_true, y_pred)
        return alpha * soft_loss + (1. - alpha) * hard_loss

    # Compile the student model with the new distillation loss
    student.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
                    loss=lambda y_true, y_pred: distillation_loss(y_true, y_pred, teacher_preds),
                    metrics=['accuracy'])

    # Train the student model
    student.fit(x_train, y_train, batch_size=32, epochs=10, validation_data=(x_test, y_test),
                callbacks=[LearningRateScheduler(lr_scheduler)], verbose=0)

    # Predict and evaluate
    start_time = time.time()
    y_pred_probs = student.predict(x_test)
    inference_time = time.time() - start_time
    y_pred = np.argmax(y_pred_probs, axis=1)
    y_true = np.argmax(y_test, axis=1)

    # Calculate and store F1-score, accuracy, precision, recall, and inference time
    f1 = f1_score(y_true, y_pred, average='weighted')
    acc = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted')
    recall = recall_score(y_true, y_pred, average='weighted')

    # Append the results
    f1_scores.append(f1)
    accuracies.append(acc)
    precisions.append(precision)
    recalls.append(recall)
    inference_times.append(inference_time)

    # Print classification report
    print(f"=== Classification Report for Alpha: {alpha} ===")
    print(classification_report(y_true, y_pred, target_names=lb.classes_))
    print(f"Inference Time: {inference_time:.4f} seconds\n")
    print(f"Alpha: {alpha} - F1 Score: {f1:.4f}, Accuracy: {acc:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}")

# Run evaluation for each alpha
for alpha in alpha_values:
    evaluate_student_with_alpha(alpha)

# Plot F1-Score vs. Alpha
plt.figure(figsize=(7, 5))
plt.plot(alpha_values, f1_scores, marker='o', color='b')
plt.xlabel("Alpha Values")
plt.ylabel("F1-Score Of Student Model")
plt.grid(True)
plt.savefig("f1_score_vs_alpha.pdf")
plt.show()

# Plot Accuracy vs. Alpha
plt.figure(figsize=(7, 5))
plt.plot(alpha_values, accuracies, marker='o', color='g')
plt.xlabel("Alpha Values")
plt.ylabel("Accuracy Of Student Model")
plt.grid(True)
plt.savefig("accuracy_vs_alpha.pdf")
plt.show()

# Plot Precision vs. Alpha
plt.figure(figsize=(7, 5))
plt.plot(alpha_values, precisions, marker='o', color='orange')
plt.xlabel("Alpha Values")
plt.ylabel("Precision Of Student Model")
plt.grid(True)
plt.savefig("precision_vs_alpha.pdf")
plt.show()

# Plot Recall vs. Alpha
plt.figure(figsize=(7, 5))
plt.plot(alpha_values, recalls, marker='o', color='red')
plt.xlabel("Alpha Values")
plt.ylabel("Recall Of Student Model")
plt.grid(True)
plt.savefig("recall_vs_alpha.pdf")
plt.show()

# Plot Inference Time vs. Alpha
plt.figure(figsize=(7, 5))
plt.plot(alpha_values, inference_times, marker='o', color='purple')
plt.xlabel("Alpha Values")
plt.ylabel("Inference Time Of Student Model (in seconds)")
plt.grid(True)
plt.savefig("inference_time_vs_alpha.pdf")
plt.show()
# Out:
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 66s 84ms/step
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step
# === Classification Report for Alpha: 0.0 ===
#                        precision    recall  f1-score   support
#
#              airplane       0.81      0.56      0.66       142
#               airport       0.42      0.33      0.37       136
#      baseball_diamond       0.63      0.65      0.64       151
#      basketball_court       0.36      0.24      0.29       147
#                 beach       0.86      0.73      0.79       138
#                bridge       0.68      0.77      0.72       137
#             chaparral       0.75      0.92      0.82       122
#                church       0.44      0.49      0.46       171
#     circular_farmland       0.81      0.68      0.74       141
#                 cloud       0.73      0.82      0.77       157
#       commercial_area       0.37      0.50      0.43       154
#     dense_residential       0.48      0.66      0.55       153
#                desert       0.90      0.84      0.87       158
#                forest       0.83      0.89      0.86       127
#               freeway       0.55      0.44      0.49       135
#           golf_course       0.69      0.71      0.70       137
#    ground_track_field       0.56      0.54      0.55       147
#                harbor       0.85      0.75      0.80       137
#       industrial_area       0.50      0.54      0.52       138
#          intersection       0.54      0.61      0.58       140
#                island       0.91      0.86      0.88       142
#                  lake       0.83      0.79      0.81       151
#                meadow       0.81      0.82      0.82       142
#    medium_residential       0.40      0.46      0.43       124
#      mobile_home_park       0.64      0.44      0.52       124
#              mountain       0.46      0.67      0.55       141
#              overpass       0.51      0.57      0.54       130
#                palace       0.36      0.27      0.31       139
#           parking_lot       0.80      0.45      0.58       142
#               railway       0.39      0.49      0.44       141
#       railway_station       0.29      0.35      0.31       150
#  rectangular_farmland       0.50      0.43      0.47       138
#                 river       0.60      0.51      0.55       115
#            roundabout       0.43      0.24      0.31       144
#                runway       0.64      0.55      0.59       119
#               sea_ice       0.80      0.91      0.85       134
#                  ship       0.44      0.50      0.47       135
#              snowberg       0.80      0.68      0.74       152
#    sparse_residential       0.62      0.72      0.66       144
#               stadium       0.79      0.54      0.64       138
#          storage_tank       0.53      0.53      0.53       129
#          tennis_court       0.33      0.48      0.39       147
#               terrace       0.62      0.66      0.64       146
# thermal_power_station       0.39      0.38      0.38       138
#               wetland       0.57      0.68      0.62       127
#
#              accuracy                           0.59      6300
#             macro avg       0.61      0.59      0.59      6300
#          weighted avg       0.60      0.59      0.59      6300
#
# Inference Time: 4.3133 seconds
#
# Alpha: 0.0 - F1 Score: 0.5913, Accuracy: 0.5917, Precision: 0.6044, Recall: 0.5917
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step
# === Classification Report for Alpha: 0.05 ===
#                        precision    recall  f1-score   support
#
#              airplane       0.61      0.58      0.60       142
#               airport       0.47      0.23      0.31       136
#      baseball_diamond       0.68      0.60      0.64       151
#      basketball_court       0.32      0.24      0.27       147
#                 beach       0.76      0.71      0.73       138
#                bridge       0.69      0.74      0.71       137
#             chaparral       0.77      0.93      0.84       122
#                church       0.46      0.44      0.45       171
#     circular_farmland       0.83      0.71      0.76       141
#                 cloud       0.79      0.80      0.79       157
#       commercial_area       0.52      0.38      0.44       154
#     dense_residential       0.51      0.60      0.55       153
#                desert       0.80      0.89      0.84       158
#                forest       0.78      0.88      0.83       127
#               freeway       0.44      0.50      0.47       135
#           golf_course       0.58      0.79      0.67       137
#    ground_track_field       0.70      0.44      0.54       147
#                harbor       0.83      0.78      0.80       137
#       industrial_area       0.70      0.45      0.55       138
#          intersection       0.56      0.58      0.57       140
#                island       0.94      0.86      0.90       142
#                  lake       0.81      0.81      0.81       151
#                meadow       0.79      0.83      0.81       142
#    medium_residential       0.34      0.48      0.40       124
#      mobile_home_park       0.46      0.61      0.53       124
#              mountain       0.54      0.40      0.46       141
#              overpass       0.57      0.54      0.55       130
#                palace       0.31      0.26      0.28       139
#           parking_lot       0.52      0.56      0.54       142
#               railway       0.41      0.48      0.44       141
#       railway_station       0.38      0.25      0.30       150
#  rectangular_farmland       0.46      0.47      0.47       138
#                 river       0.57      0.54      0.56       115
#            roundabout       0.32      0.33      0.32       144
#                runway       0.48      0.62      0.54       119
#               sea_ice       0.88      0.92      0.90       134
#                  ship       0.46      0.62      0.53       135
#              snowberg       0.78      0.81      0.79       152
#    sparse_residential       0.63      0.67      0.65       144
#               stadium       0.62      0.69      0.65       138
#          storage_tank       0.53      0.53      0.53       129
#          tennis_court       0.31      0.35      0.33       147
#               terrace       0.66      0.59      0.62       146
# thermal_power_station       0.42      0.40      0.41       138
#               wetland       0.53      0.69      0.60       127
#
#              accuracy                           0.59      6300
#             macro avg       0.59      0.59      0.58      6300
#          weighted avg       0.59      0.59      0.58      6300
#
# Inference Time: 6.0073 seconds
#
# Alpha: 0.05 - F1 Score: 0.5844, Accuracy: 0.5889, Precision: 0.5908, Recall: 0.5889
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step
# === Classification Report for Alpha: 0.1 ===
#                        precision    recall  f1-score   support
#
#              airplane       0.68      0.57      0.62       142
#               airport       0.36      0.38      0.37       136
#      baseball_diamond       0.59      0.67      0.63       151
#      basketball_court       0.27      0.14      0.19       147
#                 beach       0.78      0.72      0.75       138
#                bridge       0.74      0.64      0.69       137
#             chaparral       0.73      0.93      0.82       122
#                church       0.47      0.41      0.44       171
#     circular_farmland       0.79      0.74      0.76       141
#                 cloud       0.65      0.86      0.74       157
#       commercial_area       0.39      0.53      0.45       154
#     dense_residential       0.48      0.63      0.54       153
#                desert       0.83      0.89      0.86       158
#                forest       0.78      0.91      0.84       127
#               freeway       0.56      0.45      0.50       135
#           golf_course       0.70      0.61      0.65       137
#    ground_track_field       0.60      0.41      0.49       147
#                harbor       0.88      0.73      0.80       137
#       industrial_area       0.63      0.51      0.57       138
#          intersection       0.51      0.56      0.54       140
#                island       0.90      0.87      0.88       142
#                  lake       0.81      0.79      0.80       151
#                meadow       0.83      0.82      0.82       142
#    medium_residential       0.36      0.56      0.44       124
#      mobile_home_park       0.56      0.48      0.51       124
#              mountain       0.52      0.45      0.48       141
#              overpass       0.56      0.57      0.57       130
#                palace       0.36      0.23      0.28       139
#           parking_lot       0.63      0.56      0.59       142
#               railway       0.40      0.47      0.43       141
#       railway_station       0.34      0.34      0.34       150
#  rectangular_farmland       0.50      0.46      0.48       138
#                 river       0.52      0.61      0.56       115
#            roundabout       0.38      0.33      0.35       144
#                runway       0.52      0.55      0.53       119
#               sea_ice       0.79      0.92      0.85       134
#                  ship       0.60      0.48      0.53       135
#              snowberg       0.71      0.78      0.75       152
#    sparse_residential       0.67      0.55      0.60       144
#               stadium       0.63      0.69      0.66       138
#          storage_tank       0.47      0.59      0.52       129
#          tennis_court       0.39      0.29      0.34       147
#               terrace       0.55      0.75      0.63       146
# thermal_power_station       0.39      0.40      0.40       138
#               wetland       0.56      0.61      0.58       127
#
#              accuracy                           0.59      6300
#             macro avg       0.59      0.59      0.58      6300
#          weighted avg       0.59      0.59      0.58      6300
#
# Inference Time: 4.3974 seconds
#
# Alpha: 0.1 - F1 Score: 0.5809, Accuracy: 0.5860, Precision: 0.5859, Recall: 0.5860
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step
# === Classification Report for Alpha: 0.15 ===
#                        precision    recall  f1-score   support
#
#              airplane       0.70      0.64      0.67       142
#               airport       0.38      0.37      0.38       136
#      baseball_diamond       0.61      0.62      0.62       151
#      basketball_court       0.38      0.21      0.27       147
#                 beach       0.83      0.67      0.74       138
#                bridge       0.68      0.71      0.69       137
#             chaparral       0.79      0.94      0.86       122
#                church       0.44      0.43      0.44       171
#     circular_farmland       0.82      0.70      0.76       141
#                 cloud       0.81      0.75      0.77       157
#       commercial_area       0.45      0.33      0.38       154
#     dense_residential       0.53      0.63      0.58       153
#                desert       0.83      0.85      0.84       158
#                forest       0.86      0.80      0.83       127
#               freeway       0.43      0.49      0.46       135
#           golf_course       0.68      0.62      0.65       137
#    ground_track_field       0.53      0.45      0.49       147
#                harbor       0.86      0.69      0.76       137
#       industrial_area       0.52      0.54      0.53       138
#          intersection       0.59      0.47      0.52       140
#                island       0.94      0.82      0.87       142
#                  lake       0.82      0.77      0.80       151
#                meadow       0.75      0.86      0.80       142
#    medium_residential       0.38      0.46      0.42       124
#      mobile_home_park       0.53      0.51      0.52       124
#              mountain       0.37      0.66      0.47       141
#              overpass       0.57      0.61      0.59       130
#                palace       0.32      0.31      0.32       139
#           parking_lot       0.65      0.54      0.59       142
#               railway       0.44      0.45      0.45       141
#       railway_station       0.37      0.39      0.38       150
#  rectangular_farmland       0.53      0.41      0.46       138
#                 river       0.47      0.57      0.51       115
#            roundabout       0.42      0.38      0.40       144
#                runway       0.52      0.64      0.58       119
#               sea_ice       0.94      0.90      0.92       134
#                  ship       0.52      0.49      0.50       135
#              snowberg       0.65      0.82      0.72       152
#    sparse_residential       0.66      0.62      0.64       144
#               stadium       0.69      0.64      0.66       138
#          storage_tank       0.56      0.51      0.54       129
#          tennis_court       0.32      0.44      0.37       147
#               terrace       0.62      0.58      0.60       146
# thermal_power_station       0.43      0.46      0.45       138
#               wetland       0.53      0.69      0.60       127
#
#              accuracy                           0.59      6300
#             macro avg       0.59      0.59      0.59      6300
#          weighted avg       0.59      0.59      0.59      6300
#
# Inference Time: 5.2743 seconds
#
# Alpha: 0.15 - F1 Score: 0.5856, Accuracy: 0.5854, Precision: 0.5946, Recall: 0.5854
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step
# === Classification Report for Alpha: 0.2 ===
#                        precision    recall  f1-score   support
#
#              airplane       0.60      0.62      0.61       142
#               airport       0.35      0.35      0.35       136
#      baseball_diamond       0.59      0.66      0.62       151
#      basketball_court       0.32      0.31      0.32       147
#                 beach       0.70      0.74      0.72       138
#                bridge       0.69      0.73      0.71       137
#             chaparral       0.91      0.91      0.91       122
#                church       0.41      0.32      0.36       171
#     circular_farmland       0.83      0.65      0.73       141
#                 cloud       0.80      0.74      0.77       157
#       commercial_area       0.37      0.53      0.44       154
#     dense_residential       0.52      0.51      0.52       153
#                desert       0.87      0.88      0.88       158
#                forest       0.85      0.87      0.86       127
#               freeway       0.50      0.47      0.48       135
#           golf_course       0.61      0.69      0.65       137
#    ground_track_field       0.57      0.46      0.51       147
#                harbor       0.79      0.76      0.78       137
#       industrial_area       0.70      0.46      0.55       138
#          intersection       0.58      0.48      0.52       140
#                island       0.88      0.88      0.88       142
#                  lake       0.84      0.79      0.82       151
#                meadow       0.85      0.75      0.80       142
#    medium_residential       0.44      0.46      0.45       124
#      mobile_home_park       0.52      0.53      0.53       124
#              mountain       0.51      0.38      0.43       141
#              overpass       0.50      0.55      0.53       130
#                palace       0.27      0.33      0.30       139
#           parking_lot       0.55      0.51      0.53       142
#               railway       0.43      0.33      0.38       141
#       railway_station       0.39      0.30      0.34       150
#  rectangular_farmland       0.42      0.41      0.41       138
#                 river       0.53      0.62      0.57       115
#            roundabout       0.36      0.34      0.35       144
#                runway       0.42      0.71      0.52       119
#               sea_ice       0.82      0.90      0.86       134
#                  ship       0.43      0.51      0.47       135
#              snowberg       0.70      0.80      0.74       152
#    sparse_residential       0.60      0.67      0.63       144
#               stadium       0.58      0.67      0.62       138
#          storage_tank       0.54      0.56      0.55       129
#          tennis_court       0.43      0.27      0.33       147
#               terrace       0.69      0.58      0.63       146
# thermal_power_station       0.32      0.47      0.38       138
#               wetland       0.62      0.57      0.59       127
#
#              accuracy                           0.58      6300
#             macro avg       0.58      0.58      0.58      6300
#          weighted avg       0.58      0.58      0.57      6300
#
# Inference Time: 4.2939 seconds
#
# Alpha: 0.2 - F1 Score: 0.5749, Accuracy: 0.5757, Precision: 0.5830, Recall: 0.5757
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step
# === Classification Report for Alpha: 0.25 ===
#                        precision    recall  f1-score   support
#
#              airplane       0.61      0.66      0.63       142
#               airport       0.38      0.40      0.39       136
#      baseball_diamond       0.60      0.66      0.63       151
#      basketball_court       0.32      0.25      0.28       147
#                 beach       0.70      0.72      0.71       138
#                bridge       0.71      0.73      0.72       137
#             chaparral       0.92      0.90      0.91       122
#                church       0.49      0.37      0.42       171
#     circular_farmland       0.78      0.65      0.71       141
#                 cloud       0.77      0.81      0.79       157
#       commercial_area       0.47      0.40      0.43       154
#     dense_residential       0.49      0.56      0.52       153
#                desert       0.77      0.89      0.82       158
#                forest       0.87      0.82      0.85       127
#               freeway       0.55      0.40      0.46       135
#           golf_course       0.62      0.68      0.65       137
#    ground_track_field       0.58      0.41      0.48       147
#                harbor       0.83      0.68      0.75       137
#       industrial_area       0.59      0.53      0.56       138
#          intersection       0.43      0.49      0.46       140
#                island       0.91      0.81      0.86       142
#                  lake       0.83      0.80      0.82       151
#                meadow       0.78      0.82      0.80       142
#    medium_residential       0.37      0.36      0.37       124
#      mobile_home_park       0.37      0.55      0.44       124
#              mountain       0.57      0.43      0.49       141
#              overpass       0.60      0.52      0.55       130
#                palace       0.31      0.29      0.30       139
#           parking_lot       0.55      0.52      0.53       142
#               railway       0.44      0.40      0.42       141
#       railway_station       0.35      0.37      0.36       150
#  rectangular_farmland       0.42      0.47      0.45       138
#                 river       0.56      0.50      0.53       115
#            roundabout       0.34      0.34      0.34       144
#                runway       0.48      0.61      0.54       119
#               sea_ice       0.98      0.81      0.89       134
#                  ship       0.44      0.61      0.51       135
#              snowberg       0.71      0.77      0.74       152
#    sparse_residential       0.63      0.61      0.62       144
#               stadium       0.52      0.71      0.60       138
#          storage_tank       0.40      0.62      0.48       129
#          tennis_court       0.34      0.29      0.32       147
#               terrace       0.61      0.59      0.60       146
# thermal_power_station       0.35      0.38      0.36       138
#               wetland       0.75      0.51      0.61       127
#
#              accuracy                           0.57      6300
#             macro avg       0.58      0.57      0.57      6300
#          weighted avg       0.58      0.57      0.57      6300
#
# Inference Time: 10.4067 seconds
#
# Alpha: 0.25 - F1 Score: 0.5705, Accuracy: 0.5708, Precision: 0.5792, Recall: 0.5708
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step
# === Classification Report for Alpha: 0.3 ===
#                        precision    recall  f1-score   support
#
#              airplane       0.67      0.56      0.61       142
#               airport       0.34      0.39      0.36       136
#      baseball_diamond       0.68      0.57      0.62       151
#      basketball_court       0.27      0.24      0.25       147
#                 beach       0.81      0.70      0.75       138
#                bridge       0.70      0.70      0.70       137
#             chaparral       0.86      0.90      0.88       122
#                church       0.48      0.43      0.46       171
#     circular_farmland       0.79      0.68      0.73       141
#                 cloud       0.74      0.75      0.74       157
#       commercial_area       0.47      0.45      0.46       154
#     dense_residential       0.45      0.61      0.52       153
#                desert       0.82      0.89      0.85       158
#                forest       0.78      0.85      0.82       127
#               freeway       0.52      0.39      0.45       135
#           golf_course       0.60      0.64      0.62       137
#    ground_track_field       0.58      0.45      0.51       147
#                harbor       0.78      0.68      0.72       137
#       industrial_area       0.61      0.46      0.53       138
#          intersection       0.43      0.49      0.46       140
#                island       0.94      0.82      0.88       142
#                  lake       0.81      0.78      0.80       151
#                meadow       0.79      0.82      0.81       142
#    medium_residential       0.35      0.44      0.39       124
#      mobile_home_park       0.39      0.44      0.41       124
#              mountain       0.52      0.48      0.50       141
#              overpass       0.59      0.54      0.56       130
#                palace       0.26      0.36      0.30       139
#           parking_lot       0.65      0.45      0.53       142
#               railway       0.39      0.48      0.43       141
#       railway_station       0.39      0.35      0.37       150
#  rectangular_farmland       0.44      0.43      0.43       138
#                 river       0.50      0.62      0.55       115
#            roundabout       0.31      0.38      0.34       144
#                runway       0.48      0.61      0.54       119
#               sea_ice       0.82      0.89      0.85       134
#                  ship       0.47      0.49      0.48       135
#              snowberg       0.65      0.77      0.70       152
#    sparse_residential       0.64      0.57      0.60       144
#               stadium       0.67      0.61      0.64       138
#          storage_tank       0.49      0.44      0.46       129
#          tennis_court       0.32      0.35      0.34       147
#               terrace       0.56      0.63      0.60       146
# thermal_power_station       0.40      0.36      0.38       138
#               wetland       0.65      0.57      0.61       127
#
#              accuracy                           0.57      6300
#             macro avg       0.58      0.57      0.57      6300
#          weighted avg       0.58      0.57      0.57      6300
#
# Inference Time: 5.0839 seconds
#
# Alpha: 0.3 - F1 Score: 0.5675, Accuracy: 0.5659, Precision: 0.5756, Recall: 0.5659
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step
# === Classification Report for Alpha: 0.35 ===
#                        precision    recall  f1-score   support
#
#              airplane       0.53      0.61      0.56       142
#               airport       0.40      0.26      0.32       136
#      baseball_diamond       0.74      0.52      0.61       151
#      basketball_court       0.26      0.18      0.21       147
#                 beach       0.77      0.59      0.67       138
#                bridge       0.77      0.63      0.69       137
#             chaparral       0.86      0.91      0.88       122
#                church       0.43      0.37      0.40       171
#     circular_farmland       0.84      0.59      0.69       141
#                 cloud       0.75      0.78      0.77       157
#       commercial_area       0.46      0.38      0.41       154
#     dense_residential       0.49      0.55      0.52       153
#                desert       0.84      0.90      0.87       158
#                forest       0.46      0.91      0.61       127
#               freeway       0.44      0.43      0.44       135
#           golf_course       0.59      0.65      0.62       137
#    ground_track_field       0.53      0.40      0.46       147
#                harbor       0.81      0.66      0.73       137
#       industrial_area       0.61      0.51      0.55       138
#          intersection       0.49      0.50      0.50       140
#                island       0.94      0.82      0.88       142
#                  lake       0.82      0.81      0.81       151
#                meadow       0.76      0.87      0.81       142
#    medium_residential       0.42      0.38      0.40       124
#      mobile_home_park       0.36      0.44      0.40       124
#              mountain       0.52      0.49      0.50       141
#              overpass       0.69      0.44      0.54       130
#                palace       0.30      0.31      0.30       139
#           parking_lot       0.46      0.55      0.50       142
#               railway       0.43      0.50      0.46       141
#       railway_station       0.34      0.27      0.30       150
#  rectangular_farmland       0.52      0.40      0.45       138
#                 river       0.45      0.62      0.52       115
#            roundabout       0.44      0.29      0.35       144
#                runway       0.52      0.57      0.55       119
#               sea_ice       0.73      0.91      0.81       134
#                  ship       0.50      0.49      0.50       135
#              snowberg       0.27      0.86      0.41       152
#    sparse_residential       0.57      0.56      0.57       144
#               stadium       0.80      0.59      0.68       138
#          storage_tank       0.51      0.50      0.50       129
#          tennis_court       0.40      0.24      0.30       147
#               terrace       0.56      0.56      0.56       146
# thermal_power_station       0.40      0.36      0.38       138
#               wetland       0.73      0.56      0.63       127
#
#              accuracy                           0.55      6300
#             macro avg       0.57      0.55      0.55      6300
#          weighted avg       0.57      0.55      0.55      6300
#
# Inference Time: 4.5435 seconds
#
# Alpha: 0.35 - F1 Score: 0.5467, Accuracy: 0.5481, Precision: 0.5671, Recall: 0.5481
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step
# === Classification Report for Alpha: 0.4 ===
#                        precision    recall  f1-score   support
#
#              airplane       0.59      0.58      0.59       142
#               airport       0.36      0.40      0.38       136
#      baseball_diamond       0.75      0.46      0.57       151
#      basketball_court       0.38      0.20      0.27       147
#                 beach       0.74      0.62      0.68       138
#                bridge       0.76      0.68      0.72       137
#             chaparral       0.89      0.91      0.90       122
#                church       0.48      0.34      0.40       171
#     circular_farmland       0.76      0.67      0.71       141
#                 cloud       0.44      0.84      0.58       157
#       commercial_area       0.45      0.39      0.42       154
#     dense_residential       0.51      0.60      0.55       153
#                desert       0.89      0.86      0.87       158
#                forest       0.42      0.92      0.57       127
#               freeway       0.55      0.36      0.43       135
#           golf_course       0.62      0.62      0.62       137
#    ground_track_field       0.54      0.42      0.47       147
#                harbor       0.89      0.72      0.79       137
#       industrial_area       0.67      0.47      0.55       138
#          intersection       0.57      0.43      0.49       140
#                island       0.93      0.78      0.85       142
#                  lake       0.85      0.74      0.79       151
#                meadow       0.81      0.83      0.82       142
#    medium_residential       0.42      0.34      0.38       124
#      mobile_home_park       0.43      0.47      0.45       124
#              mountain       0.51      0.55      0.53       141
#              overpass       0.52      0.52      0.52       130
#                palace       0.32      0.28      0.30       139
#           parking_lot       0.62      0.47      0.54       142
#               railway       0.41      0.52      0.46       141
#       railway_station       0.31      0.30      0.31       150
#  rectangular_farmland       0.50      0.43      0.47       138
#                 river       0.49      0.56      0.52       115
#            roundabout       0.39      0.34      0.36       144
#                runway       0.45      0.50      0.47       119
#               sea_ice       0.83      0.85      0.84       134
#                  ship       0.47      0.57      0.52       135
#              snowberg       0.29      0.83      0.43       152
#    sparse_residential       0.65      0.58      0.61       144
#               stadium       0.63      0.67      0.65       138
#          storage_tank       0.42      0.42      0.42       129
#          tennis_court       0.45      0.20      0.28       147
#               terrace       0.62      0.60      0.61       146
# thermal_power_station       0.34      0.30      0.32       138
#               wetland       0.71      0.56      0.63       127
#
#              accuracy                           0.55      6300
#             macro avg       0.57      0.55      0.55      6300
#          weighted avg       0.57      0.55      0.55      6300
#
# Inference Time: 5.2765 seconds
#
# Alpha: 0.4 - F1 Score: 0.5463, Accuracy: 0.5478, Precision: 0.5699, Recall: 0.5478
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step
# === Classification Report for Alpha: 0.45 ===
#                        precision    recall  f1-score   support
#
#              airplane       0.55      0.60      0.57       142
#               airport       0.43      0.35      0.38       136
#      baseball_diamond       0.60      0.58      0.59       151
#      basketball_court       0.31      0.18      0.23       147
#                 beach       0.74      0.64      0.69       138
#                bridge       0.77      0.53      0.63       137
#             chaparral       0.88      0.88      0.88       122
#                church       0.41      0.28      0.33       171
#     circular_farmland       0.72      0.64      0.68       141
#                 cloud       0.43      0.83      0.57       157
#       commercial_area       0.53      0.31      0.39       154
#     dense_residential       0.57      0.56      0.56       153
#                desert       0.78      0.87      0.82       158
#                forest       0.63      0.88      0.73       127
#               freeway       0.49      0.39      0.43       135
#           golf_course       0.61      0.61      0.61       137
#    ground_track_field       0.62      0.33      0.43       147
#                harbor       0.82      0.66      0.73       137
#       industrial_area       0.71      0.44      0.54       138
#          intersection       0.50      0.39      0.44       140
#                island       0.94      0.81      0.87       142
#                  lake       0.89      0.71      0.79       151
#                meadow       0.73      0.86      0.79       142
#    medium_residential       0.37      0.33      0.35       124
#      mobile_home_park       0.18      0.55      0.27       124
#              mountain       0.56      0.47      0.51       141
#              overpass       0.52      0.35      0.41       130
#                palace       0.34      0.27      0.30       139
#           parking_lot       0.64      0.38      0.48       142
#               railway       0.32      0.48      0.39       141
#       railway_station       0.34      0.22      0.27       150
#  rectangular_farmland       0.39      0.43      0.41       138
#                 river       0.55      0.55      0.55       115
#            roundabout       0.36      0.34      0.35       144
#                runway       0.41      0.58      0.48       119
#               sea_ice       0.84      0.88      0.86       134
#                  ship       0.47      0.44      0.45       135
#              snowberg       0.26      0.78      0.39       152
#    sparse_residential       0.55      0.60      0.58       144
#               stadium       0.65      0.60      0.63       138
#          storage_tank       0.45      0.36      0.40       129
#          tennis_court       0.34      0.18      0.24       147
#               terrace       0.55      0.53      0.54       146
# thermal_power_station       0.43      0.25      0.31       138
#               wetland       0.67      0.57      0.62       127
#
#              accuracy                           0.52      6300
#             macro avg       0.55      0.52      0.52      6300
#          weighted avg       0.55      0.52      0.52      6300
#
# Inference Time: 10.4057 seconds
#
# Alpha: 0.45 - F1 Score: 0.5204, Accuracy: 0.5202, Precision: 0.5516, Recall: 0.5202
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step
# === Classification Report for Alpha: 0.5 ===
#                        precision    recall  f1-score   support
#
#              airplane       0.60      0.62      0.61       142
#               airport       0.36      0.30      0.33       136
#      baseball_diamond       0.67      0.51      0.58       151
#      basketball_court       0.38      0.18      0.24       147
#                 beach       0.69      0.63      0.66       138
#                bridge       0.77      0.60      0.67       137
#             chaparral       0.89      0.89      0.89       122
#                church       0.44      0.27      0.34       171
#     circular_farmland       0.83      0.60      0.70       141
#                 cloud       0.49      0.86      0.62       157
#       commercial_area       0.42      0.38      0.40       154
#     dense_residential       0.44      0.69      0.53       153
#                desert       0.86      0.87      0.86       158
#                forest       0.45      0.89      0.60       127
#               freeway       0.63      0.36      0.45       135
#           golf_course       0.63      0.58      0.60       137
#    ground_track_field       0.62      0.36      0.46       147
#                harbor       0.88      0.64      0.74       137
#       industrial_area       0.71      0.46      0.56       138
#          intersection       0.59      0.44      0.50       140
#                island       0.91      0.82      0.86       142
#                  lake       0.92      0.72      0.81       151
#                meadow       0.82      0.82      0.82       142
#    medium_residential       0.39      0.38      0.39       124
#      mobile_home_park       0.34      0.56      0.42       124
#              mountain       0.52      0.47      0.49       141
#              overpass       0.50      0.52      0.51       130
#                palace       0.33      0.23      0.27       139
#           parking_lot       0.67      0.46      0.54       142
#               railway       0.24      0.57      0.34       141
#       railway_station       0.42      0.25      0.32       150
#  rectangular_farmland       0.55      0.39      0.46       138
#                 river       0.50      0.60      0.55       115
#            roundabout       0.34      0.39      0.36       144
#                runway       0.49      0.64      0.55       119
#               sea_ice       0.87      0.88      0.87       134
#                  ship       0.53      0.41      0.46       135
#              snowberg       0.26      0.83      0.39       152
#    sparse_residential       0.58      0.56      0.57       144
#               stadium       0.68      0.59      0.63       138
#          storage_tank       0.50      0.39      0.43       129
#          tennis_court       0.32      0.17      0.22       147
#               terrace       0.60      0.53      0.56       146
# thermal_power_station       0.39      0.28      0.32       138
#               wetland       0.67      0.54      0.60       127
#
#              accuracy                           0.53      6300
#             macro avg       0.57      0.54      0.54      6300
#          weighted avg       0.57      0.53      0.53      6300
#
# Inference Time: 6.3440 seconds
#
# Alpha: 0.5 - F1 Score: 0.5340, Accuracy: 0.5338, Precision: 0.5698, Recall: 0.5338
